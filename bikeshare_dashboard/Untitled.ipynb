# %%
import pandas as pd
import glob
import os

# %%
# Path to the folder containing your files
folder_path = '../dataset'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):  # Assuming all files are CSV, you can change the condition accordingly
        file_path = os.path.join(folder_path, filename)
        # Try different encodings to read the file
        for encoding in ['utf-8', 'latin-1']:  # You can add more encodings to try if needed
            try:
                df = pd.read_csv(file_path, encoding=encoding)
                dfs.append(df)  # Append the DataFrame to the list
                break  # Break the loop if reading is successful
            except UnicodeDecodeError:
                print(f"Error decoding file {filename} with encoding {encoding}. Trying another encoding...")

# Concatenate all DataFrames in the list into one
combined_df = pd.concat(dfs, ignore_index=True)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_21768\3920506851.py:14: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding=encoding)
# C:\Users\prana\AppData\Local\Temp\ipykernel_21768\3920506851.py:14: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding=encoding)
# C:\Users\prana\AppData\Local\Temp\ipykernel_21768\3920506851.py:14: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding=encoding)
# C:\Users\prana\AppData\Local\Temp\ipykernel_21768\3920506851.py:14: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding=encoding)
# Error decoding file Mobi_System_Data_2023-06.csv with encoding utf-8. Trying another encoding...
# Error decoding file Mobi_System_Data_2023-07.csv with encoding utf-8. Trying another encoding...
# Error decoding file Mobi_System_Data_2023-08.csv with encoding utf-8. Trying another encoding...

# %%
combined_df.head()
# Out:
#           Departure            Return Electric bike  \
# 0   2023-02-01 0:00   2023-02-01 0:00         False
# 1  2023-01-31 23:00   2023-02-01 0:00         False
# 2  2023-01-31 23:00   2023-02-01 0:00         False
# 3  2023-01-31 23:00   2023-02-01 0:00         False
# 4  2023-01-31 23:00  2023-01-31 23:00         False
#
#            Departure station              Return station    Membership type  \
# 0        0228 Keefer & Hawks  0232 Britannia Parking Lot     Community Pass
# 1  0035 Hastings & Broughton        0190 Melville & Bute  365 Day Pass Plus
# 2     0058 Richards & Smithe       0071 14th & Granville        30 Day Pass
# 3    0063 Robson & Granville       0030 Abbott & Cordova  365 Day Pass Plus
# 4             0008 8th & Ash         0199 Georgia & Main        30 Day Pass
#
#    Covered distance (m)  Duration (sec.)  Departure temperature (C)  \
# 0                1474.0            515.0                        2.0
# 1               11086.0           3410.0                        3.0
# 2                4318.0           1005.0                        3.0
# 3                3375.0           2221.0                        6.0
# 4                2605.0            473.0                        3.0
#
#    Return temperature (C)  Stopover duration (sec.)  Number of stopovers  Bike
# 0                     3.0                       0.0                  0.0   NaN
# 1                     5.0                     587.0                  1.0   NaN
# 2                     6.0                       0.0                  0.0   NaN
# 3                     5.0                    1044.0                  5.0   NaN
# 4                     5.0                       0.0                  0.0   NaN

# %%
combined_df = combined_df.drop(['Bike'], axis = 1)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549268 entries, 0 to 1549267
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Departure                  1385687 non-null  object
#  1   Return                     1385559 non-null  object
#  2   Electric bike              1385687 non-null  object
#  3   Departure station          1385661 non-null  object
#  4   Return station             1385457 non-null  object
#  5   Membership type            1383384 non-null  object
#  6   Covered distance (m)       1385687 non-null  float64
#  7   Duration (sec.)            1385687 non-null  float64
#  8   Departure temperature (C)  1385687 non-null  float64
#  9   Return temperature (C)     1385687 non-null  float64
#  10  Stopover duration (sec.)   1385687 non-null  float64
#  11  Number of stopovers        1385687 non-null  float64
# dtypes: float64(6), object(6)
# memory usage: 141.8+ MB

# %%
combined_df.isna().sum()
# Out:
# Departure                    163581
# Return                       163709
# Electric bike                163581
# Departure station            163607
# Return station               163811
# Membership type              165884
# Covered distance (m)         163581
# Duration (sec.)              163581
# Departure temperature (C)    163581
# Return temperature (C)       163581
# Stopover duration (sec.)     163581
# Number of stopovers          163581
# dtype: int64

# %%
combined_df[combined_df['Departure'].isna()]
# Out:
#        Departure Return Electric bike Departure station Return station  \
# 48042        NaN    NaN           NaN               NaN            NaN
# 48043        NaN    NaN           NaN               NaN            NaN
# 48044        NaN    NaN           NaN               NaN            NaN
# 48045        NaN    NaN           NaN               NaN            NaN
# 48046        NaN    NaN           NaN               NaN            NaN
# ...          ...    ...           ...               ...            ...
# 404891       NaN    NaN           NaN               NaN            NaN
# 404892       NaN    NaN           NaN               NaN            NaN
# 404893       NaN    NaN           NaN               NaN            NaN
# 404894       NaN    NaN           NaN               NaN            NaN
# 404895       NaN    NaN           NaN               NaN            NaN
#
#        Membership type  Covered distance (m)  Duration (sec.)  \
# 48042              NaN                   NaN              NaN
# 48043              NaN                   NaN              NaN
# 48044              NaN                   NaN              NaN
# 48045              NaN                   NaN              NaN
# 48046              NaN                   NaN              NaN
# ...                ...                   ...              ...
# 404891             NaN                   NaN              NaN
# 404892             NaN                   NaN              NaN
# 404893             NaN                   NaN              NaN
# 404894             NaN                   NaN              NaN
# 404895             NaN                   NaN              NaN
#
#         Departure temperature (C)  Return temperature (C)  \
# 48042                         NaN                     NaN
# 48043                         NaN                     NaN
# 48044                         NaN                     NaN
# 48045                         NaN                     NaN
# 48046                         NaN                     NaN
# ...                           ...                     ...
# 404891                        NaN                     NaN
# 404892                        NaN                     NaN
# 404893                        NaN                     NaN
# 404894                        NaN                     NaN
# 404895                        NaN                     NaN
#
#         Stopover duration (sec.)  Number of stopovers
# 48042                        NaN                  NaN
# 48043                        NaN                  NaN
# 48044                        NaN                  NaN
# 48045                        NaN                  NaN
# 48046                        NaN                  NaN
# ...                          ...                  ...
# 404891                       NaN                  NaN
# 404892                       NaN                  NaN
# 404893                       NaN                  NaN
# 404894                       NaN                  NaN
# 404895                       NaN                  NaN
#
# [163581 rows x 12 columns]

# %%
combined_df.dropna(inplace=True)

# %%
combined_df.isna().sum()
# Out:
# Departure                    0
# Return                       0
# Electric bike                0
# Departure station            0
# Return station               0
# Membership type              0
# Covered distance (m)         0
# Duration (sec.)              0
# Departure temperature (C)    0
# Return temperature (C)       0
# Stopover duration (sec.)     0
# Number of stopovers          0
# dtype: int64

# %%
combined_df['Departure'].unique()
# Out:
# array(['2023-02-01 0:00', '2023-01-31 23:00', '2023-01-31 22:00', ...,
#        '2024-01-01 3:00', '2024-01-01 2:00', '2024-01-01 1:00'],
#       dtype=object)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1383296 entries, 0 to 1549267
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Departure                  1383296 non-null  object
#  1   Return                     1383296 non-null  object
#  2   Electric bike              1383296 non-null  object
#  3   Departure station          1383296 non-null  object
#  4   Return station             1383296 non-null  object
#  5   Membership type            1383296 non-null  object
#  6   Covered distance (m)       1383296 non-null  float64
#  7   Duration (sec.)            1383296 non-null  float64
#  8   Departure temperature (C)  1383296 non-null  float64
#  9   Return temperature (C)     1383296 non-null  float64
#  10  Stopover duration (sec.)   1383296 non-null  float64
#  11  Number of stopovers        1383296 non-null  float64
# dtypes: float64(6), object(6)
# memory usage: 137.2+ MB

# %%
filtered_df = combined_df[combined_df['Departure'].str.startswith('2023-06-05')]

# %%
filtered_df.head()
# Out:
#                Departure            Return Electric bike  \
# 677310  2023-06-05 23:00   2023-06-06 0:00          True
# 677311  2023-06-05 23:00  2023-06-05 23:00          True
# 677312  2023-06-05 23:00   2023-06-06 0:00          True
# 677313  2023-06-05 23:00   2023-06-06 0:00         False
# 677314  2023-06-05 23:00   2023-06-06 0:00         False
#
#               Departure station           Return station  \
# 677310  0631 Lakewood & Triumph  0631 Lakewood & Triumph
# 677311  0631 Lakewood & Triumph  0631 Lakewood & Triumph
# 677312  0631 Lakewood & Triumph  0631 Lakewood & Triumph
# 677313          0198 5th & Main   0084 Beach & Broughton
# 677314       0028 Davie & Beach     0137 Beach & Seymour
#
#                    Membership type  Covered distance (m)  Duration (sec.)  \
# 677310                         VIP                5899.0           2143.0
# 677311                         VIP                   0.0             15.0
# 677312                         VIP                5805.0           2192.0
# 677313                 30 Day Pass                4894.0           1432.0
# 677314  365 Corporate Plus Renewal                2103.0            521.0
#
#         Departure temperature (C)  Return temperature (C)  \
# 677310                       11.0                    10.0
# 677311                       11.0                     7.0
# 677312                       12.0                    16.0
# 677313                       19.0                    20.0
# 677314                       16.0                    19.0
#
#         Stopover duration (sec.)  Number of stopovers
# 677310                     386.0                  1.0
# 677311                       0.0                  0.0
# 677312                     417.0                  1.0
# 677313                       0.0                  0.0
# 677314                       0.0                  0.0

# %%
len(combined_df)
# Out:
# 1383296

# %%
combined_df['Membership type'].value_counts().index
# Out:
# Index(['Pay Per Ride', '365 Day Pass Standard', '30 Day Pass',
#        '365 Day Pass Plus', '24 Hour', '365 Corporate Plus Renewal',
#        '365 Corporate Plus', '365 Day Pass Plus SALE',
#        '365 Corporate Standard', '365 Day Pass Standard SALE',
#        'Community Pass', 'VIP', 'Community Pass E-bike (PWD)',
#        'Community Pass E-bike', '365 Corporate Standard Renewal',
#        '365 Day Founding Standard', '365 Day Founding Plus',
#        'UBC Inclusive Corporate Pass', 'Archived Monthly Standard',
#        'Herbaland Pass', 'Archived Monthly Plus', 'Maintenance',
#        'VIP Tour E-bike', 'VIP Tour', 'Limited Classic Bikes Only (30 min)',
#        'Limited Classic Bikes Only (60 min)', 'Youth Community Pass'],
#       dtype='object')

# %%
counts_series = combined_df['Membership type'].value_counts()
index_list = counts_series.index.tolist()
counts_list = counts_series.tolist()

# %%
label = index_list[:18]

# %%
label.append('Others')

# %%
label
# Out:
# ['Pay Per Ride',
#  '365 Day Pass Standard',
#  '30 Day Pass',
#  '365 Day Pass Plus',
#  '24 Hour',
#  '365 Corporate Plus Renewal',
#  '365 Corporate Plus',
#  '365 Day Pass Plus SALE',
#  '365 Corporate Standard',
#  '365 Day Pass Standard SALE',
#  'Community Pass',
#  'VIP',
#  'Community Pass E-bike (PWD)',
#  'Community Pass E-bike',
#  '365 Corporate Standard Renewal',
#  '365 Day Founding Standard',
#  '365 Day Founding Plus',
#  'UBC Inclusive Corporate Pass',
#  'Others']

# %%
value = counts_list[:18]

# %%
value.append(sum(counts_list[18:]))

# %%
import plotly.graph_objects as go
import plotly.express as px

labels = label
values = value
total_count = sum(values)

fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=0.5, textinfo='none', marker=dict(colors=px.colors.sequential.Reds[::-1]))])

fig.add_annotation(text='Number of Rides<br>' + str(total_count), showarrow=False, font=dict(size=15), x=0.5, y=0.5)

fig.update_layout(title='Rides by Membership Type', title_x=0.5, title_font_size=20, showlegend=False)

fig.show()
# Out:
# <div>                            <div id="fe0c5ee3-e0bd-4753-9d52-15577e712426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe0c5ee3-e0bd-4753-9d52-15577e712426")) {                    Plotly.newPlot(                        "fe0c5ee3-e0bd-4753-9d52-15577e712426",                        [{"hole":0.5,"labels":["Pay Per Ride","365 Day Pass Standard","30 Day Pass","365 Day Pass Plus","24 Hour","365 Corporate Plus Renewal","365 Corporate Plus","365 Day Pass Plus SALE","365 Corporate Standard","365 Day Pass Standard SALE","Community Pass","VIP","Community Pass E-bike (PWD)","Community Pass E-bike","365 Corporate Standard Renewal","365 Day Founding Standard","365 Day Founding Plus","UBC Inclusive Corporate Pass","Others"],"marker":{"colors":["rgb(103,0,13)","rgb(165,15,21)","rgb(203,24,29)","rgb(239,59,44)","rgb(251,106,74)","rgb(252,146,114)","rgb(252,187,161)","rgb(254,224,210)","rgb(255,245,240)"]},"textinfo":"none","values":[290789,208267,173987,136665,119060,54852,51070,48638,44658,41908,38155,35610,33110,32647,24736,21294,21159,4918,1773],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %%
combined_df[['Departure temperature (C)', 'Duration (sec.)']]
# Out:
#          Departure temperature (C)  Duration (sec.)
# 0                              2.0            515.0
# 1                              3.0           3410.0
# 2                              3.0           1005.0
# 3                              6.0           2221.0
# 4                              3.0            473.0
# ...                            ...              ...
# 1549263                       10.0           3086.0
# 1549264                        9.0             22.0
# 1549265                        6.0            796.0
# 1549266                        9.0            416.0
# 1549267                        6.0            486.0
#
# [1383296 rows x 2 columns]

# %%
combined_df.head()
# Out:
#           Departure            Return Electric bike  \
# 0   2023-02-01 0:00   2023-02-01 0:00         False
# 1  2023-01-31 23:00   2023-02-01 0:00         False
# 2  2023-01-31 23:00   2023-02-01 0:00         False
# 3  2023-01-31 23:00   2023-02-01 0:00         False
# 4  2023-01-31 23:00  2023-01-31 23:00         False
#
#            Departure station              Return station    Membership type  \
# 0        0228 Keefer & Hawks  0232 Britannia Parking Lot     Community Pass
# 1  0035 Hastings & Broughton        0190 Melville & Bute  365 Day Pass Plus
# 2     0058 Richards & Smithe       0071 14th & Granville        30 Day Pass
# 3    0063 Robson & Granville       0030 Abbott & Cordova  365 Day Pass Plus
# 4             0008 8th & Ash         0199 Georgia & Main        30 Day Pass
#
#    Covered distance (m)  Duration (sec.)  Departure temperature (C)  \
# 0                1474.0            515.0                        2.0
# 1               11086.0           3410.0                        3.0
# 2                4318.0           1005.0                        3.0
# 3                3375.0           2221.0                        6.0
# 4                2605.0            473.0                        3.0
#
#    Return temperature (C)  Stopover duration (sec.)  Number of stopovers
# 0                     3.0                       0.0                  0.0
# 1                     5.0                     587.0                  1.0
# 2                     6.0                       0.0                  0.0
# 3                     5.0                    1044.0                  5.0
# 4                     5.0                       0.0                  0.0

# %%
len(combined_df[combined_df['Duration (sec.)'] < 0])
# Out:
# 57

# %%
df = combined_df[combined_df['Duration (sec.)'] >= 0]

# %%
df.head()
# Out:
#           Departure            Return Electric bike  \
# 0   2023-02-01 0:00   2023-02-01 0:00         False
# 1  2023-01-31 23:00   2023-02-01 0:00         False
# 2  2023-01-31 23:00   2023-02-01 0:00         False
# 3  2023-01-31 23:00   2023-02-01 0:00         False
# 4  2023-01-31 23:00  2023-01-31 23:00         False
#
#            Departure station              Return station    Membership type  \
# 0        0228 Keefer & Hawks  0232 Britannia Parking Lot     Community Pass
# 1  0035 Hastings & Broughton        0190 Melville & Bute  365 Day Pass Plus
# 2     0058 Richards & Smithe       0071 14th & Granville        30 Day Pass
# 3    0063 Robson & Granville       0030 Abbott & Cordova  365 Day Pass Plus
# 4             0008 8th & Ash         0199 Georgia & Main        30 Day Pass
#
#    Covered distance (m)  Duration (sec.)  Departure temperature (C)  \
# 0                1474.0            515.0                        2.0
# 1               11086.0           3410.0                        3.0
# 2                4318.0           1005.0                        3.0
# 3                3375.0           2221.0                        6.0
# 4                2605.0            473.0                        3.0
#
#    Return temperature (C)  Stopover duration (sec.)  Number of stopovers
# 0                     3.0                       0.0                  0.0
# 1                     5.0                     587.0                  1.0
# 2                     6.0                       0.0                  0.0
# 3                     5.0                    1044.0                  5.0
# 4                     5.0                       0.0                  0.0

# %%
sorted(combined_df['Departure station'].unique())
# Out:
# ['0001 10th & Cambie',
#  '0002 Burrard Station (Melville & Dunsmuir)',
#  '0004 Yaletown-Roundhouse Station',
#  '0005 Dunsmuir & Beatty',
#  '0006 Olympic Village Station',
#  '0007 12th & Yukon (City Hall)',
#  '0008 8th & Ash',
#  '0009 Spyglass & Seawall',
#  '0010 Stamps Landing',
#  '0011 Ontario & Seawall',
#  '0012 Dunsmuir & Richards',
#  '0014 Canada Place',
#  '0015 Granville & Georgia',
#  '0016 Pender & Burrard',
#  '0017 Marinaside & Davie',
#  '0019 Robson & Hornby',
#  '0021 Cordova & Granville',
#  '0024 Hornby & Pender',
#  '0025 Homer & Robson (Vancouver Public Library)',
#  '0026 Beatty & Robson',
#  '0027 Beatty & Nelson',
#  '0028 Davie & Beach',
#  '0030 Abbott & Cordova',
#  '0031 Morton & Denman',
#  '0032 Comox & Denman',
#  '0034 Cordova & Bute',
#  '0035 Hastings & Broughton',
#  '0036 Bute & Robson',
#  '0037 Hornby & Nelson',
#  '0039 Helmcken & Burrard',
#  '0040 Cardero & Davie',
#  '0041 Cardero & Robson',
#  '0044 Pacific & Richards',
#  '0045 Beach & Hornby',
#  '0047 Chilco & Beach',
#  '0048 Comox & Broughton',
#  '0050 Bute & Comox',
#  '0052 Cambie & Water',
#  '0053 Keefer & Abbott',
#  '0054 Expo & Carrall',
#  '0055 Keefer & Columbia',
#  '0057 Marinaside & Cooperage',
#  '0058 Richards & Smithe',
#  '0060 Bidwell & Burnaby',
#  '0063 Robson & Granville',
#  '0064 Expo & Smithe',
#  '0065 Cypress & Cornwall',
#  '0066 Anderson & 2nd',
#  '0068 Cypress & 10th',
#  '0069 7th & Granville',
#  '0070 10th & Granville',
#  '0071 14th & Granville',
#  '0072 14th & Cambie',
#  '0073 Ontario & 5th',
#  '0074 10th & Main',
#  '0075 Arbutus & 10th',
#  '0076 Cypress & 4th',
#  '0077 Vanier Park',
#  '0078 Nelson & Mainland',
#  '0079 Nelson & Richards',
#  '0081 7th & Heather',
#  '0082 Richards & Davie',
#  '0083 Aquatic Centre',
#  '0084 Beach & Broughton',
#  '0087 Broughton & Davie',
#  '0088 Harwood & Bute',
#  '0089 Burrard & Drake',
#  '0092 Chilco & Barclay',
#  '0093 Chilco & Robson',
#  '0096 Nicola & Robson',
#  '0098 Carrall & Hastings',
#  '0099 Vancouver Art Gallery - North Plaza',
#  "0099 ax·\x9b\x13YnYq Xwtl'e7e\x01nk1 Square - Vancouver Art Gallery",
#  "0099 ax·\x9b\x13YnYq Xwtl'e7én5 Square - Vancouver Art Gallery",
#  "0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery",
#  "0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery",
#  '0100 Stanley Park - Prospect Point',
#  '0101 Stanley Park - Vancouver Aquarium',
#  '0102 Stanley Park - Second Beach North',
#  '0103 Stanley Park - Third Beach Parking Lot',
#  '0104 Stanley Park - Second Beach South',
#  '0105 Stanley Park - Totem Poles',
#  '0106 Heather & 14th',
#  '0107 8th & Ontario',
#  '0108 1st & Chestnut',
#  '0109 7th & Arbutus',
#  '0110 5th & Arbutus',
#  '0112 10th & Oak',
#  '0113 Arbutus & 16th',
#  '0114 Cypress & 14th',
#  '0115 Cypress & 16th',
#  '0119 3rd & Quebec',
#  '0122 Haro & Denman',
#  '0123 Georgia & Thurlow',
#  '0124 Richards & Cordova',
#  '0126 Thurlow & Pendrell',
#  '0129 Richards & Robson',
#  '0130 Heather & 16th',
#  '0132 14th & Ontario',
#  '0133 Ontario & 16th',
#  '0134 14th & Main',
#  '0136 David Lam Park',
#  '0136 David Lam Park - West',
#  '0137 Beach & Seymour',
#  '0138 Richards & Helmcken',
#  '0139 Burrard & 4th',
#  '0140 Burrard & 7th',
#  '0142 Beach & Cardero',
#  '0143 South False Creek Seawall',
#  '0144 Wylie & 2nd',
#  '0147 Chestnut & McNicoll',
#  '0148 Creekside Park North',
#  '0150 Alexander & Main',
#  '0152 Arbutus Greenway & 14th',
#  '0153 Arbutus Greenway & Fir',
#  '0154 Kitsilano Beach Park',
#  '0155 Arbutus & McNicoll',
#  '0159 Vine & 4th',
#  '0161 Alexander & Dunlevy',
#  '0165 Columbia & 5th',
#  '0166 Alder & 11th',
#  '0170 8th & Yukon',
#  '0171 Yukon & 6th',
#  '0172 10th & Columbia',
#  '0173 Columbia & 1st',
#  '0174 1st & Manitoba',
#  '0176 10th & Ontario',
#  '0177 Quebec & 1st',
#  '0179 11th & Kingsway',
#  '0180 Columbia & 14th',
#  '0186 10th & Kingsway',
#  '0187 Bute & Davie',
#  '0189 Granville Island',
#  '0190 Melville & Bute',
#  '0191 7th & Laurel',
#  '0192 7th &  Alder',
#  '0193 Science World',
#  '0196 Hornby & Drake',
#  '0197 1st & Scotia',
#  '0198 5th & Main',
#  '0199 Georgia & Main',
#  '0200 Cardero & Bayshore',
#  '0201 Rogers Tower',
#  '0201 Shaw Tower',
#  '0202 14th & Oak',
#  '0203 Pine & 14th',
#  '0204 York & Yew',
#  '0205 Pine & 10th',
#  '0206 8th & Scotia',
#  '0207 Alberni & Jervis',
#  '0209 Stanley Park - Information Booth',
#  '0210 Burrard & 14th',
#  '0211 14th & Alder',
#  '0212 Union & Dunlevy',
#  '0213 Pender & Gore',
#  '0215 Princess & Union',
#  '0217 Smithe & Burrard',
#  '0218 Carrall & Seawall',
#  '0219 Hawks & Union',
#  '0221 Glen & Union',
#  '0222 Adanac & McLean',
#  '0223 Commercial & Adanac',
#  '0224 Pender & Commercial',
#  '0225 McLean & Pender',
#  '0227 Campbell & Hastings',
#  '0228 Keefer & Hawks',
#  '0229 Keefer & Princess',
#  '0230 Alexander & Railway',
#  '0231 Napier & Commercial',
#  '0232 Britannia Parking Lot',
#  '0233 Thornton & National',
#  '0235 Charles & Commercial',
#  '0236 Keith & 6th',
#  '0237 Glen & 6th',
#  '0237 Glen & 6th - Removed Permanently',
#  '0239 Grant & Commercial',
#  '0240 2nd & Commercial',
#  '0241 4th & Commercial',
#  '0242 8th & Commercial',
#  '0244 10th & Commercial',
#  '0245 Woodland & 10th',
#  '0246 Glen & Broadway',
#  '0248 St George & Broadway',
#  '0249 7th & Woodland',
#  '0250 Woodland & 4th',
#  '0252 Woodland & Graveley',
#  '0253 Charles & Woodland',
#  '0254 Grandview & Commercial',
#  '0255 18th & Main',
#  '0256 Prince Edward & 16th',
#  '0257 Prince Edward & 14th',
#  '0258 13th & St George',
#  '0260 10th & Fraser',
#  '0261 8th & Fraser',
#  '0262 8th & Prince Edward',
#  '0265 St Catherines & 10th',
#  '0266 St Catherines & 7th',
#  '0272 Pender & Victoria',
#  '0273 Victoria & 4th',
#  '0274 Victoria & 10th',
#  '0278 15th & Victoria (Trout Lake)',
#  '0280 Triumph & Victoria',
#  '0281 Windsor & 14th',
#  '0282 14th & Fraser',
#  '0283 15th & Knight',
#  '0285 Commercial & Pandora',
#  '0287 Carolina & Great Northern Way',
#  '0297 6th & Prince Edward',
#  '0298 6th & Carolina',
#  '0300 Bute & Barclay',
#  '0305 Georgia & Homer',
#  '0308 Seymour & Cordova',
#  '0310 Jervis & Robson',
#  '0311 13th & Cambie',
#  '0313 Nelson & Denman',
#  '0314 Rolston & Granville',
#  '0315 1st & Fir',
#  '0352 Commercial & 20th',
#  '0354 Station & Terminal',
#  '0400 Jericho Beach',
#  '0401 Wallace & 4th',
#  '0403 Highbury & 8th',
#  '0410 Alma & Point Grey',
#  '0414 Dunbar & 6th',
#  '0415 Dunbar & Broadway',
#  '0431 Blenheim & 4th',
#  '0440 Point Grey & Blenheim',
#  '0443 Balaclava & 6th',
#  '0444 Balaclava & Broadway',
#  '0450 Point Grey & Bayswater',
#  '0452 8th & Macdonald',
#  '0460 Trafalgar & Cornwall',
#  '0464 Trafalgar & Broadway',
#  '0470 Balsam & Cornwall',
#  '0480 Arbutus & Nanton',
#  '0482 East Blvd & 37th',
#  '0484 Yew & Broadway',
#  '0505 28th & Willow',
#  '0511 18th & Heather',
#  '0516 Heather & 29th',
#  '0524 King Edward & Cambie',
#  '0526 29th & Cambie',
#  '0531 18th & Cambie',
#  '0532 22nd & Cambie',
#  '0554 Ontario & 23rd',
#  '0557 30th & Ontario',
#  '0561 20th & Main',
#  '0563 22nd & Main',
#  '0565 27th & Main',
#  '0611 Wall & Eton',
#  '0621 Lakewood & Oxford',
#  '0631 Lakewood & Triumph',
#  '0642 Franklin & Nanaimo',
#  '0715 Trimble & 8th',
#  '0716 Sasamat & 10th',
#  '0980 Workshop - Balancer Bike Check In',
#  '0981 Workshop - Service Complete',
#  '0982 Workshop - Bike Testing',
#  '0987 Quebec Yard - Rogers',
#  '0991 HQ Workshop',
#  '0992 Workshop - Return to Smoove',
#  '0994 Workshop - Transmitter Testing',
#  '0995 Workshop - Transmitter On Deck',
#  '0997 Workshop - Demo Station',
#  '1000 Temporary Station',
#  '1000 Vancouver PRIDE Valet Station',
#  '1002 PNE - Hastings & Windermere',
#  '1002 Production MFC 2022',
#  '2132 IK Barber Learning Centre',
#  '2143 War Memorial Gym',
#  '2143 War Memorial Gymnasium',
#  '2156 Pharmaceutical Sciences',
#  '3000 Temporary Station - Celebration of Light']

# %%
len(sorted(df['Return station'].unique()))
# Out:
# 265

# %%
df['Departure code'] = df['Departure station'].apply(lambda x: x[:4])
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_8588\1111642315.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Station'] = df['Departure station'].apply(lambda x: x[5:])
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_8588\3230713834.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
combined_df['Departure code'] = combined_df['Departure station'].apply(lambda x: x[:4])

# %%
df.head()
# Out:
#           Departure            Return Electric bike  \
# 0   2023-02-01 0:00   2023-02-01 0:00         False
# 1  2023-01-31 23:00   2023-02-01 0:00         False
# 2  2023-01-31 23:00   2023-02-01 0:00         False
# 3  2023-01-31 23:00   2023-02-01 0:00         False
# 4  2023-01-31 23:00  2023-01-31 23:00         False
#
#            Departure station              Return station    Membership type  \
# 0        0228 Keefer & Hawks  0232 Britannia Parking Lot     Community Pass
# 1  0035 Hastings & Broughton        0190 Melville & Bute  365 Day Pass Plus
# 2     0058 Richards & Smithe       0071 14th & Granville        30 Day Pass
# 3    0063 Robson & Granville       0030 Abbott & Cordova  365 Day Pass Plus
# 4             0008 8th & Ash         0199 Georgia & Main        30 Day Pass
#
#    Covered distance (m)  Duration (sec.)  Departure temperature (C)  \
# 0                1474.0            515.0                        2.0
# 1               11086.0           3410.0                        3.0
# 2                4318.0           1005.0                        3.0
# 3                3375.0           2221.0                        6.0
# 4                2605.0            473.0                        3.0
#
#    Return temperature (C)  Stopover duration (sec.)  Number of stopovers  \
# 0                     3.0                       0.0                  0.0
# 1                     5.0                     587.0                  1.0
# 2                     6.0                       0.0                  0.0
# 3                     5.0                    1044.0                  5.0
# 4                     5.0                       0.0                  0.0
#
#   Departure code               Station
# 0           0228        Keefer & Hawks
# 1           0035  Hastings & Broughton
# 2           0058     Richards & Smithe
# 3           0063    Robson & Granville
# 4           0008             8th & Ash

# %%
df[['Departure code', 'Departure station']]
# Out:
#         Departure code                                  Departure station
# 0                 0228                                0228 Keefer & Hawks
# 1                 0035                          0035 Hastings & Broughton
# 2                 0058                             0058 Richards & Smithe
# 3                 0063                            0063 Robson & Granville
# 4                 0008                                     0008 8th & Ash
# ...                ...                                                ...
# 1549263           0099  0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver A...
# 1549264           0099  0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver A...
# 1549265           0716                                0716 Sasamat & 10th
# 1549266           0126                            0126 Thurlow & Pendrell
# 1549267           0041                              0041 Cardero & Robson
#
# [1383239 rows x 2 columns]

# %%
len(sorted(df['Departure station'].unique()))
# Out:
# 273

# %%
df.loc[df['Departure station'].str.startswith('0099'), 'Departure station'] = "0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery North Plaza"
df.loc[df['Return station'].str.startswith('0099'), 'Return station'] = "0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery North Plaza"

# %%
df.loc[df['Departure station'].str.startswith('0136'), 'Departure station'] = '0136 David Lam Park - West'
df.loc[df['Return station'].str.startswith('0136'), 'Return station'] = '0136 David Lam Park - West'

# %%
df.loc[df['Departure station'].str.startswith('0201'), 'Departure station'] = '0201 Shaw Tower'
df.loc[df['Return station'].str.startswith('0201'), 'Return station'] = '0201 Shaw Tower'

# %%
df.loc[df['Departure station'].str.startswith('0237'), 'Departure station'] = '0237 Glen & 6th'
df.loc[df['Return station'].str.startswith('0237'), 'Return station'] = '0237 Glen & 6th'

# %%
df.loc[df['Departure station'].str.startswith('1002'), 'Departure station'] = '1002 PNE - Hastings & Windermere'
df.loc[df['Return station'].str.startswith('1002'), 'Return station'] = '1002 PNE - Hastings & Windermere'

# %%
df.loc[df['Departure station'].str.startswith('2143'), 'Departure station'] = '2143 War Memorial Gym'
df.loc[df['Return station'].str.startswith('2143'), 'Return station'] = '2143 War Memorial Gym'

# %%
df.loc[df['Departure station'].str.startswith('0154'), 'Departure station'] = '0155 Arbutus & McNicoll'
df.loc[df['Return station'].str.startswith('0154'), 'Return station'] = '0155 Arbutus & McNicoll'

# %%
df.loc[df['Departure station'].str.startswith('0165'), 'Departure station'] = '0150 Alexander & Main'
df.loc[df['Return station'].str.startswith('0165'), 'Return station'] = '0150 Alexander & Main'

# %%
values_to_remove = ['0980 Workshop - Balancer Bike Check In', '0981 Workshop - Service Complete', '0982 Workshop - Bike Testing', '0987 Quebec Yard - Rogers', '0991 HQ Workshop', '0992 Workshop - Return to Smoove', '0994 Workshop - Transmitter Testing', '0995 Workshop - Transmitter On Deck', '0997 Workshop - Demo Station', '0985 Quebec Yard - To Service', '1000 Temporary Station', '1000 Vancouver PRIDE Valet Station', '3000 Temporary Station - Celebration of Light']
df = df[~df['Departure station'].isin(values_to_remove)]
df = df[~df['Return station'].isin(values_to_remove)]

# %%
len(sorted(df['Return station'].unique()))
# Out:
# 250

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1379112 entries, 0 to 1549267
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Departure                  1379112 non-null  datetime64[ns]
#  1   Return                     1379112 non-null  object
#  2   Electric bike              1379112 non-null  object
#  3   Departure station          1379112 non-null  object
#  4   Return station             1379112 non-null  object
#  5   Membership type            1379112 non-null  object
#  6   Covered distance (m)       1379112 non-null  float64
#  7   Duration (sec.)            1379112 non-null  float64
#  8   Departure temperature (C)  1379112 non-null  float64
#  9   Return temperature (C)     1379112 non-null  float64
#  10  Stopover duration (sec.)   1379112 non-null  float64
#  11  Number of stopovers        1379112 non-null  float64
#  12  Month                      1379112 non-null  object
#  13  Season                     1379112 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 157.8+ MB

# %%
dfc = pd.read_csv('data.csv')

# %%
dfc.head()
# Out:
#                                       Station  \
# 0                          0001 10th & Cambie
# 1  0002 Burrard Station (Melville & Dunsmuir)
# 2            0004 Yaletown-Roundhouse Station
# 3                      0005 Dunsmuir & Beatty
# 4                0006 Olympic Village Station
#
#                                 Coordinates comments
# 0                (49.2622822, -123.1142145)      NaN
# 1  (49.28645885053061, -123.12102864288579)      NaN
# 2                (49.2744594, -123.1217156)      NaN
# 3                (49.2797102, -123.1100831)      NaN
# 4                (49.2665609, -123.1156986)      NaN

# %%
dfc.rename(columns={'Station': 'Departure station'}, inplace=True)

# %%
dfc.head()
# Out:
#                             Departure station  \
# 0                          0001 10th & Cambie
# 1  0002 Burrard Station (Melville & Dunsmuir)
# 2            0004 Yaletown-Roundhouse Station
# 3                      0005 Dunsmuir & Beatty
# 4                0006 Olympic Village Station
#
#                                 Coordinates comments
# 0                (49.2622822, -123.1142145)      NaN
# 1  (49.28645885053061, -123.12102864288579)      NaN
# 2                (49.2744594, -123.1217156)      NaN
# 3                (49.2797102, -123.1100831)      NaN
# 4                (49.2665609, -123.1156986)      NaN

# %%
dfc.drop(columns=['comments'], inplace=True)

# %%
merged_df = pd.merge(df, dfc, on='Departure station')

# %%
merged_df.tail()
# Out:
#                   Departure            Return Electric bike  \
# 1379108 2024-01-10 13:00:00  2024-01-10 13:00         False
# 1379109 2024-01-08 09:00:00  2024-01-08 10:00          True
# 1379110 2024-01-04 17:00:00  2024-01-04 17:00          True
# 1379111 2024-01-04 17:00:00  2024-01-04 17:00          True
# 1379112 2024-01-04 17:00:00  2024-01-04 17:00          True
#
#                     Departure station                  Return station  \
# 1379108  2156 Pharmaceutical Sciences    2156 Pharmaceutical Sciences
# 1379109  2156 Pharmaceutical Sciences    2156 Pharmaceutical Sciences
# 1379110  2156 Pharmaceutical Sciences  2132 IK Barber Learning Centre
# 1379111  2156 Pharmaceutical Sciences    2156 Pharmaceutical Sciences
# 1379112  2156 Pharmaceutical Sciences    2156 Pharmaceutical Sciences
#
#                       Membership type  Covered distance (m)  Duration (sec.)  \
# 1379108  UBC Inclusive Corporate Pass                   2.0             57.0
# 1379109   Community Pass E-bike (PWD)                1742.0           1820.0
# 1379110                  Pay Per Ride                1100.0            307.0
# 1379111                  Pay Per Ride                   0.0            113.0
# 1379112                  Pay Per Ride                   0.0             27.0
#
#          Departure temperature (C)  Return temperature (C)  \
# 1379108                        7.0                     6.0
# 1379109                        0.0                    -1.0
# 1379110                        4.0                     8.0
# 1379111                        4.0                     8.0
# 1379112                        0.0                     7.0
#
#          Stopover duration (sec.)  Number of stopovers Month  Season  \
# 1379108                       0.0                  0.0   Jan  Winter
# 1379109                       0.0                  0.0   Jan  Winter
# 1379110                       0.0                  0.0   Jan  Winter
# 1379111                       0.0                  0.0   Jan  Winter
# 1379112                       0.0                  0.0   Jan  Winter
#
#                                      Coordinates
# 1379108  (49.26474842889402, -123.2430141715432)
# 1379109  (49.26474842889402, -123.2430141715432)
# 1379110  (49.26474842889402, -123.2430141715432)
# 1379111  (49.26474842889402, -123.2430141715432)
# 1379112  (49.26474842889402, -123.2430141715432)

# %%
df.head()
# Out:
#             Departure            Return Electric bike  \
# 0 2023-02-01 00:00:00   2023-02-01 0:00         False
# 1 2023-01-31 23:00:00   2023-02-01 0:00         False
# 2 2023-01-31 23:00:00   2023-02-01 0:00         False
# 3 2023-01-31 23:00:00   2023-02-01 0:00         False
# 4 2023-01-31 23:00:00  2023-01-31 23:00         False
#
#            Departure station              Return station    Membership type  \
# 0        0228 Keefer & Hawks  0232 Britannia Parking Lot     Community Pass
# 1  0035 Hastings & Broughton        0190 Melville & Bute  365 Day Pass Plus
# 2     0058 Richards & Smithe       0071 14th & Granville        30 Day Pass
# 3    0063 Robson & Granville       0030 Abbott & Cordova  365 Day Pass Plus
# 4             0008 8th & Ash         0199 Georgia & Main        30 Day Pass
#
#    Covered distance (m)  Duration (sec.)  Departure temperature (C)  \
# 0                1474.0            515.0                        2.0
# 1               11086.0           3410.0                        3.0
# 2                4318.0           1005.0                        3.0
# 3                3375.0           2221.0                        6.0
# 4                2605.0            473.0                        3.0
#
#    Return temperature (C)  Stopover duration (sec.)  Number of stopovers  \
# 0                     3.0                       0.0                  0.0
# 1                     5.0                     587.0                  1.0
# 2                     6.0                       0.0                  0.0
# 3                     5.0                    1044.0                  5.0
# 4                     5.0                       0.0                  0.0
#
#   Month  Season
# 0   Feb  Winter
# 1   Jan  Winter
# 2   Jan  Winter
# 3   Jan  Winter
# 4   Jan  Winter

# %%
dfc.head()
# Out:
#                             Departure station  \
# 0                          0001 10th & Cambie
# 1  0002 Burrard Station (Melville & Dunsmuir)
# 2            0004 Yaletown-Roundhouse Station
# 3                      0005 Dunsmuir & Beatty
# 4                0006 Olympic Village Station
#
#                                 Coordinates
# 0                (49.2622822, -123.1142145)
# 1  (49.28645885053061, -123.12102864288579)
# 2                (49.2744594, -123.1217156)
# 3                (49.2797102, -123.1100831)
# 4                (49.2665609, -123.1156986)

# %%
# Out:
# Departure station
# Coordinates

# %%
coordinates = list(dfc['Coordinates'])

marker_locations = dfc.to_dict(orient='records')

for entry in marker_locations:
    entry['Coordinates'] = tuple(map(float, entry['Coordinates'].strip('()').split(', ')))

marker_locations
# Out:
# [{'Departure station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145)},
#  {'Departure station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579)},
#  {'Departure station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156)},
#  {'Departure station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831)},
#  {'Departure station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986)},
#  {'Departure station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551)},
#  {'Departure station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195)},
#  {'Departure station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229)},
#  {'Departure station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201)},
#  {'Departure station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968)},
#  {'Departure station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579)},
#  {'Departure station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278)},
#  {'Departure station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414)},
#  {'Departure station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171)},
#  {'Departure station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519)},
#  {'Departure station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614)},
#  {'Departure station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026)},
#  {'Departure station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602)},
#  {'Departure station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355)},
#  {'Departure station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236)},
#  {'Departure station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024)},
#  {'Departure station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991)},
#  {'Departure station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005)},
#  {'Departure station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794)},
#  {'Departure station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327)},
#  {'Departure station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827)},
#  {'Departure station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703)},
#  {'Departure station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595)},
#  {'Departure station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478)},
#  {'Departure station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469)},
#  {'Departure station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385)},
#  {'Departure station': '0041 Cardero & Robson',
#   'Coordinates': (49.2892686, -123.1326555)},
#  {'Departure station': '0044 Pacific & Richards',
#   'Coordinates': (49.2736703, -123.1270617)},
#  {'Departure station': '0045 Beach & Hornby',
#   'Coordinates': (49.2752543, -123.1325611)},
#  {'Departure station': '0047 Chilco & Beach',
#   'Coordinates': (49.289712, -123.1440153)},
#  {'Departure station': '0048 Comox & Broughton',
#   'Coordinates': (49.2853146, -123.134325)},
#  {'Departure station': '0050 Bute & Comox',
#   'Coordinates': (49.2833805, -123.1310401)},
#  {'Departure station': '0052 Cambie & Water',
#   'Coordinates': (49.2846283, -123.1086152)},
#  {'Departure station': '0053 Keefer & Abbott',
#   'Coordinates': (49.2797995, -123.1079267)},
#  {'Departure station': '0054 Expo & Carrall',
#   'Coordinates': (49.2780481, -123.1057008)},
#  {'Departure station': '0055 Keefer & Columbia',
#   'Coordinates': (49.2793015, -123.1017685)},
#  {'Departure station': '0057 Marinaside & Cooperage',
#   'Coordinates': (49.2738549, -123.114558)},
#  {'Departure station': '0058 Richards & Smithe',
#   'Coordinates': (49.27939951298386, -123.118759898409)},
#  {'Departure station': '0060 Bidwell & Burnaby',
#   'Coordinates': (49.285434929689615, -123.14183036009283)},
#  {'Departure station': '0063 Robson & Granville',
#   'Coordinates': (49.2815126, -123.1201536)},
#  {'Departure station': '0064 Expo & Smithe',
#   'Coordinates': (49.2761224, -123.1145372)},
#  {'Departure station': '0065 Cypress & Cornwall',
#   'Coordinates': (49.2727532, -123.1477204)},
#  {'Departure station': '0066 Anderson & 2nd',
#   'Coordinates': (49.2695442, -123.1378336)},
#  {'Departure station': '0068 Cypress & 10th',
#   'Coordinates': (49.264090554207186, -123.14825708079611)},
#  {'Departure station': '0069 7th & Granville',
#   'Coordinates': (49.2652855, -123.1381984)},
#  {'Departure station': '0070 10th & Granville',
#   'Coordinates': (49.26414290170466, -123.13924486700175)},
#  {'Departure station': '0071 14th & Granville',
#   'Coordinates': (49.260508441881825, -123.13948657782952)},
#  {'Departure station': '0072 14th & Cambie',
#   'Coordinates': (49.2587688, -123.1152956)},
#  {'Departure station': '0073 Ontario & 5th',
#   'Coordinates': (49.2668059, -123.1047506)},
#  {'Departure station': '0074 10th & Main',
#   'Coordinates': (49.2620812, -123.1018465)},
#  {'Departure station': '0075 Arbutus & 10th',
#   'Coordinates': (49.26318495734679, -123.15280282686798)},
#  {'Departure station': '0076 Cypress & 4th',
#   'Coordinates': (49.2682673, -123.1478672)},
#  {'Departure station': '0077 Vanier Park',
#   'Coordinates': (49.2757002, -123.14245)},
#  {'Departure station': '0078 Nelson & Mainland',
#   'Coordinates': (49.2765028, -123.1189009)},
#  {'Departure station': '0079 Nelson & Richards',
#   'Coordinates': (49.2777729, -123.1208527)},
#  {'Departure station': '0081 7th & Heather',
#   'Coordinates': (49.266060405303, -123.11937073571582)},
#  {'Departure station': '0082 Richards & Davie',
#   'Coordinates': (49.2757543, -123.1243609)},
#  {'Departure station': '0083 Aquatic Centre',
#   'Coordinates': (49.2781965, -123.1369457)},
#  {'Departure station': '0084 Beach & Broughton',
#   'Coordinates': (49.281178, -123.139029)},
#  {'Departure station': '0087 Broughton & Davie',
#   'Coordinates': (49.2837789, -123.1360038)},
#  {'Departure station': '0088 Harwood & Bute',
#   'Coordinates': (49.2802978, -123.1352757)},
#  {'Departure station': '0089 Burrard & Drake',
#   'Coordinates': (49.2781301, -123.1305274)},
#  {'Departure station': '0092 Chilco & Barclay',
#   'Coordinates': (49.2918468, -123.1407852)},
#  {'Departure station': '0093 Chilco & Robson',
#   'Coordinates': (49.2932024, -123.1386077)},
#  {'Departure station': '0096 Nicola & Robson',
#   'Coordinates': (49.2881444, -123.1320198)},
#  {'Departure station': '0098 Carrall & Hastings',
#   'Coordinates': (49.2810403, -123.1044111)},
#  {'Departure station': "0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery North Plaza",
#   'Coordinates': (49.2831979, -123.1204825)},
#  {'Departure station': '0100 Stanley Park - Prospect Point',
#   'Coordinates': (49.30309815456114, -123.15556880374768)},
#  {'Departure station': '0101 Stanley Park - Vancouver Aquarium',
#   'Coordinates': (49.299446690892594, -123.13029163125633)},
#  {'Departure station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774)},
#  {'Departure station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398)},
#  {'Departure station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901)},
#  {'Departure station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625)},
#  {'Departure station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635)},
#  {'Departure station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798)},
#  {'Departure station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997)},
#  {'Departure station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342)},
#  {'Departure station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863)},
#  {'Departure station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616)},
#  {'Departure station': '0113 Arbutus & 16th',
#   'Coordinates': (49.2576909, -123.1532696)},
#  {'Departure station': '0114 Cypress & 14th',
#   'Coordinates': (49.2592367, -123.1482565)},
#  {'Departure station': '0115 Cypress & 16th',
#   'Coordinates': (49.2575397, -123.1484736)},
#  {'Departure station': '0119 3rd & Quebec',
#   'Coordinates': (49.26834298033376, -123.10311500612258)},
#  {'Departure station': '0122 Haro & Denman',
#   'Coordinates': (49.2905224, -123.136222)},
#  {'Departure station': '0123 Georgia & Thurlow',
#   'Coordinates': (49.2860549, -123.1241903)},
#  {'Departure station': '0124 Richards & Cordova',
#   'Coordinates': (49.2844582, -123.1111846)},
#  {'Departure station': '0126 Thurlow & Pendrell',
#   'Coordinates': (49.2808952, -123.130541)},
#  {'Departure station': '0129 Richards & Robson',
#   'Coordinates': (49.2803018, -123.1177147)},
#  {'Departure station': '0130 Heather & 16th',
#   'Coordinates': (49.25676, -123.1200251)},
#  {'Departure station': '0132 14th & Ontario',
#   'Coordinates': (49.258783883228645, -123.10476859419327)},
#  {'Departure station': '0133 Ontario & 16th',
#   'Coordinates': (49.2568643, -123.1051257)},
#  {'Departure station': '0134 14th & Main',
#   'Coordinates': (49.2583966, -123.1007345)},
#  {'Departure station': '0136 David Lam Park - West',
#   'Coordinates': (49.271530026217526, -123.1260353260855)},
#  {'Departure station': '0137 Beach & Seymour',
#   'Coordinates': (49.2735405, -123.1298518)},
#  {'Departure station': '0138 Richards & Helmcken',
#   'Coordinates': (49.2771762, -123.1225069)},
#  {'Departure station': '0139 Burrard & 4th',
#   'Coordinates': (49.2677813, -123.1457589)},
#  {'Departure station': '0140 Burrard & 7th',
#   'Coordinates': (49.2652965, -123.1458088)},
#  {'Departure station': '0142 Beach & Cardero',
#   'Coordinates': (49.2832577, -123.1422531)},
#  {'Departure station': '0143 South False Creek Seawall',
#   'Coordinates': (49.2676184, -123.1277051)},
#  {'Departure station': '0144 Wylie & 2nd',
#   'Coordinates': (49.26924995007328, -123.11356358443396)},
#  {'Departure station': '0147 Chestnut & McNicoll',
#   'Coordinates': (49.2759635, -123.1460073)},
#  {'Departure station': '0148 Creekside Park North',
#   'Coordinates': (49.2756105, -123.102698)},
#  {'Departure station': '0150 Alexander & Main',
#   'Coordinates': (49.2841519, -123.0999589)},
#  {'Departure station': '0152 Arbutus Greenway & 14th',
#   'Coordinates': (49.2589484, -123.152613)},
#  {'Departure station': '0153 Arbutus Greenway & Fir',
#   'Coordinates': (49.26723164781529, -123.14117677659085)},
#  {'Departure station': '0155 Arbutus & McNicoll',
#   'Coordinates': (49.2760877, -123.1513261)},
#  {'Departure station': '0159 Vine & 4th',
#   'Coordinates': (49.2683741, -123.157433)},
#  {'Departure station': '0161 Alexander & Dunlevy',
#   'Coordinates': (49.2840577, -123.095047)},
#  {'Departure station': '0166 Alder & 11th',
#   'Coordinates': (49.2617669, -123.1314892)},
#  {'Departure station': '0170 8th & Yukon',
#   'Coordinates': (49.2639535, -123.1126594)},
#  {'Departure station': '0171 Yukon & 6th',
#   'Coordinates': (49.26713629766202, -123.11302274906645)},
#  {'Departure station': '0172 10th & Columbia',
#   'Coordinates': (49.2622196, -123.1093161)},
#  {'Departure station': '0173 Columbia & 1st',
#   'Coordinates': (49.2699811, -123.1095854)},
#  {'Departure station': '0174 1st & Manitoba',
#   'Coordinates': (49.2702382, -123.106335)},
#  {'Departure station': '0176 10th & Ontario',
#   'Coordinates': (49.26354803375647, -123.10495467282134)},
#  {'Departure station': '0177 Quebec & 1st',
#   'Coordinates': (49.27060417070058, -123.1027931410502)},
#  {'Departure station': '0179 11th & Kingsway',
#   'Coordinates': (49.2611458, -123.0974366)},
#  {'Departure station': '0180 Columbia & 14th',
#   'Coordinates': (49.2589114, -123.1095676)},
#  {'Departure station': '0186 10th & Kingsway',
#   'Coordinates': (49.2619701, -123.0973416)},
#  {'Departure station': '0187 Bute & Davie',
#   'Coordinates': (49.2820425, -123.1330451)},
#  {'Departure station': '0189 Granville Island',
#   'Coordinates': (49.2702636, -123.1349844)},
#  {'Departure station': '0190 Melville & Bute',
#   'Coordinates': (49.2877533, -123.1239048)},
#  {'Departure station': '0191 7th & Laurel',
#   'Coordinates': (49.2650434, -123.1237691)},
#  {'Departure station': '0192 7th &  Alder',
#   'Coordinates': (49.2651767, -123.1310129)},
#  {'Departure station': '0193 Science World',
#   'Coordinates': (49.2736718, -123.1022542)},
#  {'Departure station': '0196 Hornby & Drake',
#   'Coordinates': (49.27770937148666, -123.13002064251597)},
#  {'Departure station': '0197 1st & Scotia',
#   'Coordinates': (49.26933497641719, -123.09780580842329)},
#  {'Departure station': '0198 5th & Main',
#   'Coordinates': (49.268162733415146, -123.10070206403793)},
#  {'Departure station': '0199 Georgia & Main',
#   'Coordinates': (49.2785197, -123.1000524)},
#  {'Departure station': '0200 Cardero & Bayshore',
#   'Coordinates': (49.2915667, -123.1291772)},
#  {'Departure station': '0201 Shaw Tower',
#   'Coordinates': (49.2886688, -123.1182129)},
#  {'Departure station': '0202 14th & Oak',
#   'Coordinates': (49.258781, -123.1271099)},
#  {'Departure station': '0203 Pine & 14th',
#   'Coordinates': (49.258866, -123.1435154)},
#  {'Departure station': '0204 York & Yew',
#   'Coordinates': (49.2717489, -123.1554804)},
#  {'Departure station': '0205 Pine & 10th',
#   'Coordinates': (49.2629314, -123.1433487)},
#  {'Departure station': '0206 8th & Scotia',
#   'Coordinates': (49.2636196, -123.099236)},
#  {'Departure station': '0207 Alberni & Jervis',
#   'Coordinates': (49.2876362, -123.1272215)},
#  {'Departure station': '0209 Stanley Park - Information Booth',
#   'Coordinates': (49.2979505, -123.1306813)},
#  {'Departure station': '0210 Burrard & 14th',
#   'Coordinates': (49.2594325, -123.1456168)},
#  {'Departure station': '0211 14th & Alder',
#   'Coordinates': (49.2588295, -123.1313655)},
#  {'Departure station': '0212 Union & Dunlevy',
#   'Coordinates': (49.2776095, -123.095793)},
#  {'Departure station': '0213 Pender & Gore',
#   'Coordinates': (49.2802712, -123.0970897)},
#  {'Departure station': '0215 Princess & Union',
#   'Coordinates': (49.2777049, -123.0917253)},
#  {'Departure station': '0217 Smithe & Burrard',
#   'Coordinates': (49.2825174, -123.1246795)},
#  {'Departure station': '0218 Carrall & Seawall',
#   'Coordinates': (49.2762933, -123.1065399)},
#  {'Departure station': '0219 Hawks & Union',
#   'Coordinates': (49.277639941688165, -123.08739233760114)},
#  {'Departure station': '0221 Glen & Union',
#   'Coordinates': (49.27769593710045, -123.08136273191201)},
#  {'Departure station': '0222 Adanac & McLean',
#   'Coordinates': (49.2776591, -123.0735579)},
#  {'Departure station': '0223 Commercial & Adanac',
#   'Coordinates': (49.2773948, -123.0704165)},
#  {'Departure station': '0224 Pender & Commercial',
#   'Coordinates': (49.2803186, -123.0700656)},
#  {'Departure station': '0225 McLean & Pender',
#   'Coordinates': (49.2801197, -123.0741648)},
#  {'Departure station': '0227 Campbell & Hastings',
#   'Coordinates': (49.2806434, -123.084749)},
#  {'Departure station': '0228 Keefer & Hawks',
#   'Coordinates': (49.2792153, -123.0874912)},
#  {'Departure station': '0229 Keefer & Princess',
#   'Coordinates': (49.2793622, -123.0909562)},
#  {'Departure station': '0230 Alexander & Railway',
#   'Coordinates': (49.2839923, -123.0911062)},
#  {'Departure station': '0231 Napier & Commercial',
#   'Coordinates': (49.274881, -123.0692936)},
#  {'Departure station': '0232 Britannia Parking Lot',
#   'Coordinates': (49.2758553, -123.0719018)},
#  {'Departure station': '0233 Thornton & National',
#   'Coordinates': (49.2737663, -123.0927082)},
#  {'Departure station': '0235 Charles & Commercial',
#   'Coordinates': (49.2731002, -123.0699248)},
#  {'Departure station': '0236 Keith & 6th',
#   'Coordinates': (49.2649223, -123.0794519)},
#  {'Departure station': '0237 Glen & 6th',
#   'Coordinates': (49.2649024, -123.0812237)},
#  {'Departure station': '0239 Grant & Commercial',
#   'Coordinates': (49.2713808, -123.0693525)},
#  {'Departure station': '0240 2nd & Commercial',
#   'Coordinates': (49.2686186, -123.0700509)},
#  {'Departure station': '0241 4th & Commercial',
#   'Coordinates': (49.2669734, -123.0700235)},
#  {'Departure station': '0242 8th & Commercial',
#   'Coordinates': (49.2632295, -123.0704772)},
#  {'Departure station': '0244 10th & Commercial',
#   'Coordinates': (49.261412, -123.0701593)},
#  {'Departure station': '0245 Woodland & 10th',
#   'Coordinates': (49.2612322, -123.0737544)},
#  {'Departure station': '0246 Glen & Broadway',
#   'Coordinates': (49.2621862, -123.0814508)},
#  {'Departure station': '0248 St George & Broadway',
#   'Coordinates': (49.2623071, -123.0930671)},
#  {'Departure station': '0249 7th & Woodland',
#   'Coordinates': (49.2642309, -123.0738623)},
#  {'Departure station': '0250 Woodland & 4th',
#   'Coordinates': (49.2666761, -123.0734696)},
#  {'Departure station': '0252 Woodland & Graveley',
#   'Coordinates': (49.2707346, -123.0736192)},
#  {'Departure station': '0253 Charles & Woodland',
#   'Coordinates': (49.2731187, -123.0731844)},
#  {'Departure station': '0254 Grandview & Commercial',
#   'Coordinates': (49.2641012, -123.0707016)},
#  {'Departure station': '0255 18th & Main',
#   'Coordinates': (49.255730024708285, -123.1013024811912)},
#  {'Departure station': '0256 Prince Edward & 16th',
#   'Coordinates': (49.2567266, -123.0965455)},
#  {'Departure station': '0257 Prince Edward & 14th',
#   'Coordinates': (49.2581393, -123.096343)},
#  {'Departure station': '0258 13th & St George',
#   'Coordinates': (49.259405173012865, -123.09294720425774)},
#  {'Departure station': '0260 10th & Fraser',
#   'Coordinates': (49.2615005, -123.0893354)},
#  {'Departure station': '0261 8th & Fraser',
#   'Coordinates': (49.2634568, -123.0888362)},
#  {'Departure station': '0262 8th & Prince Edward',
#   'Coordinates': (49.2635225, -123.0956253)},
#  {'Departure station': '0265 St Catherines & 10th',
#   'Coordinates': (49.262577789637305, -123.08545571982644)},
#  {'Departure station': '0266 St Catherines & 7th',
#   'Coordinates': (49.26537833729386, -123.08554155051243)},
#  {'Departure station': '0272 Pender & Victoria',
#   'Coordinates': (49.2801793, -123.0660122)},
#  {'Departure station': '0273 Victoria & 4th',
#   'Coordinates': (49.2666307, -123.0658618)},
#  {'Departure station': '0274 Victoria & 10th',
#   'Coordinates': (49.2611652, -123.0660014)},
#  {'Departure station': '0278 15th & Victoria (Trout Lake)',
#   'Coordinates': (49.25703903280026, -123.06569964660144)},
#  {'Departure station': '0280 Triumph & Victoria',
#   'Coordinates': (49.2839768, -123.0652119)},
#  {'Departure station': '0281 Windsor & 14th',
#   'Coordinates': (49.2580237, -123.0833488)},
#  {'Departure station': '0282 14th & Fraser',
#   'Coordinates': (49.2579521, -123.0895274)},
#  {'Departure station': '0283 15th & Knight',
#   'Coordinates': (49.256636019684855, -123.0754796466014)},
#  {'Departure station': '0285 Commercial & Pandora',
#   'Coordinates': (49.2832115, -123.0703905)},
#  {'Departure station': '0287 Carolina & Great Northern Way',
#   'Coordinates': (49.2674701, -123.0907444)},
#  {'Departure station': '0297 6th & Prince Edward',
#   'Coordinates': (49.2652349, -123.0954559)},
#  {'Departure station': '0298 6th & Carolina',
#   'Coordinates': (49.2652155, -123.0906761)},
#  {'Departure station': '0300 Bute & Barclay',
#   'Coordinates': (49.2848699, -123.128767)},
#  {'Departure station': '0305 Georgia & Homer',
#   'Coordinates': (49.2809374, -123.1153534)},
#  {'Departure station': '0308 Seymour & Cordova',
#   'Coordinates': (49.28642858047458, -123.11229368733197)},
#  {'Departure station': '0310 Jervis & Robson',
#   'Coordinates': (49.2868529, -123.1289011)},
#  {'Departure station': '0311 13th & Cambie',
#   'Coordinates': (49.2595423, -123.114742)},
#  {'Departure station': '0313 Nelson & Denman',
#   'Coordinates': (49.289354331375506, -123.13841277397488)},
#  {'Departure station': '0314 Rolston & Granville',
#   'Coordinates': (49.27462211868453, -123.13027982879254)},
#  {'Departure station': '0315 1st & Fir',
#   'Coordinates': (49.271756811418996, -123.14194708517161)},
#  {'Departure station': '0352 Commercial & 20th',
#   'Coordinates': (49.252656, -123.067972)},
#  {'Departure station': '0354 Station & Terminal',
#   'Coordinates': (49.272223, -123.097988)},
#  {'Departure station': '0400 Jericho Beach',
#   'Coordinates': (49.27125697998983, -123.19152237543645)},
#  {'Departure station': '0401 Wallace & 4th',
#   'Coordinates': (49.2685318, -123.190208)},
#  {'Departure station': '0403 Highbury & 8th',
#   'Coordinates': (49.26563100226765, -123.18782373310832)},
#  {'Departure station': '0410 Alma & Point Grey',
#   'Coordinates': (49.2648033, -123.1858536)},
#  {'Departure station': '0414 Dunbar & 6th',
#   'Coordinates': (49.26679064939855, -123.18367399475082)},
#  {'Departure station': '0415 Dunbar & Broadway',
#   'Coordinates': (49.2647183187402, -123.18368472358655)},
#  {'Departure station': '0431 Blenheim & 4th',
#   'Coordinates': (49.269005877089526, -123.1777075368086)},
#  {'Departure station': '0440 Point Grey & Blenheim',
#   'Coordinates': (49.271561050263074, -123.17734275639324)},
#  {'Departure station': '0443 Balaclava & 6th',
#   'Coordinates': (49.26702898542659, -123.17387046009372)},
#  {'Departure station': '0444 Balaclava & Broadway',
#   'Coordinates': (49.2640934, -123.173552)},
#  {'Departure station': '0450 Point Grey & Bayswater',
#   'Coordinates': (49.27118400713191, -123.17067709339292)},
#  {'Departure station': '0452 8th & Macdonald',
#   'Coordinates': (49.2651100317576, -123.16808409339292)},
#  {'Departure station': '0460 Trafalgar & Cornwall',
#   'Coordinates': (49.27308097263876, -123.16438937543627)},
#  {'Departure station': '0464 Trafalgar & Broadway',
#   'Coordinates': (49.2639092, -123.164243)},
#  {'Departure station': '0470 Balsam & Cornwall',
#   'Coordinates': (49.272569, -123.159366)},
#  {'Departure station': '0480 Arbutus & Nanton',
#   'Coordinates': (49.2479931, -123.153038)},
#  {'Departure station': '0482 East Blvd & 37th',
#   'Coordinates': (49.238224056794316, -123.15498746009504)},
#  {'Departure station': '0484 Yew & Broadway',
#   'Coordinates': (49.26367000115968, -123.15535283310847)},
#  {'Departure station': '0505 28th & Willow',
#   'Coordinates': (49.24636906977219, -123.1243890933929)},
#  {'Departure station': '0511 18th & Heather',
#   'Coordinates': (49.25557080561342, -123.12047310381172)},
#  {'Departure station': '0516 Heather & 29th',
#   'Coordinates': (49.24615846509807, -123.1205160191547)},
#  {'Departure station': '0524 King Edward & Cambie',
#   'Coordinates': (49.2492072, -123.1161507)},
#  {'Departure station': '0526 29th & Cambie',
#   'Coordinates': (49.2451129, -123.1162559)},
#  {'Departure station': '0531 18th & Cambie',
#   'Coordinates': (49.2548234, -123.1148079)},
#  {'Departure station': '0532 22nd & Cambie',
#   'Coordinates': (49.2516355, -123.1225685)},
#  {'Departure station': '0554 Ontario & 23rd',
#   'Coordinates': (49.24982702203195, -123.10504464660185)},
#  {'Departure station': '0557 30th & Ontario',
#   'Coordinates': (49.2433945, -123.104914)},
#  {'Departure station': '0561 20th & Main',
#   'Coordinates': (49.2527004, -123.101258)},
#  {'Departure station': '0563 22nd & Main',
#   'Coordinates': (49.25125094870104, -123.10139097000348)},
#  {'Departure station': '0565 27th & Main',
#   'Coordinates': (49.24742811945479, -123.10168847514333)},
#  {'Departure station': '0611 Wall & Eton',
#   'Coordinates': (49.28835974049902, -123.06107140851543)},
#  {'Departure station': '0621 Lakewood & Oxford',
#   'Coordinates': (49.28570094059109, -123.0616071889287)},
#  {'Departure station': '0631 Lakewood & Triumph',
#   'Coordinates': (49.284124614121865, -123.06164440188009)},
#  {'Departure station': '0642 Franklin & Nanaimo',
#   'Coordinates': (49.282234980165605, -123.05699881600219)},
#  {'Departure station': '0715 Trimble & 8th',
#   'Coordinates': (49.26637088513888, -123.20618269270258)},
#  {'Departure station': '0716 Sasamat & 10th',
#   'Coordinates': (49.264151996994904, -123.20915454475092)},
#  {'Departure station': '1002 PNE - Hastings & Windermere',
#   'Coordinates': (49.2809692, -123.0358795)},
#  {'Departure station': '2132 IK Barber Learning Centre',
#   'Coordinates': (49.2676589832246, -123.25221808707906)},
#  {'Departure station': '2143 War Memorial Gym',
#   'Coordinates': (49.266796, -123.24763482487361)},
#  {'Departure station': '2156 Pharmaceutical Sciences',
#   'Coordinates': (49.26474842889402, -123.2430141715432)}]

# %%
import folium

# Define the GeoJSON feature object for Vancouver boundary
vancouver_geojson = {
    "type": "Feature",
    "properties": {
        "name": "Vancouver",
        "description": "Boundary of the city of Vancouver, British Columbia, Canada"
    }
}

# Define the center of the circle (latitude, longitude) and radius in meters
center = [49.2827, -123.1207]
radius = 5000  # in meters

# Define specific locations for markers (latitude, longitude)


# Create a Folium map centered around Vancouver
map_vancouver = folium.Map(location=[49.2827, -123.1207], zoom_start=12)

# Add GeoJSON boundary to the map
folium.GeoJson(vancouver_geojson).add_to(map_vancouver)

# Add markers to specific locations
for item in marker_locations:
    location = item["Coordinates"]
    name = item["Departure station"]
    folium.Marker(
        location=location,
        icon=folium.Icon(icon='bicycle', prefix='fa', color='red'),
        tooltip=name  # Add place name as tooltip
    ).add_to(map_vancouver)

# Display the map
map_vancouver
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c33d4513e978a53052bb8384b9a312d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c33d4513e978a53052bb8384b9a312d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c33d4513e978a53052bb8384b9a312d5 = L.map(
#                 &quot;map_c33d4513e978a53052bb8384b9a312d5&quot;,
#                 {
#                     center: [49.2827, -123.1207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ed5d1da53423452b4c70f5e0b869ea1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7ed5d1da53423452b4c70f5e0b869ea1.addTo(map_c33d4513e978a53052bb8384b9a312d5);
#
#
#
#         function geo_json_f57ae68b3f59cfd1a80c96a625dbf6ef_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f57ae68b3f59cfd1a80c96a625dbf6ef = L.geoJson(null, {
#                 onEachFeature: geo_json_f57ae68b3f59cfd1a80c96a625dbf6ef_onEachFeature,
#
#         });
#
#         function geo_json_f57ae68b3f59cfd1a80c96a625dbf6ef_add (data) {
#             geo_json_f57ae68b3f59cfd1a80c96a625dbf6ef
#                 .addData(data);
#         }
#             geo_json_f57ae68b3f59cfd1a80c96a625dbf6ef_add({&quot;properties&quot;: {&quot;description&quot;: &quot;Boundary of the city of Vancouver, British Columbia, Canada&quot;, &quot;name&quot;: &quot;Vancouver&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_f57ae68b3f59cfd1a80c96a625dbf6ef.addTo(map_c33d4513e978a53052bb8384b9a312d5);
#
#
#             var marker_9c59937a5a994cf3098af2069041fb4f = L.marker(
#                 [49.2622822, -123.1142145],
#                 {}
#             ).addTo(map_c33d4513e978a53052bb8384b9a312d5);
#
#
#             var icon_bd61cf399ffeb71304c9b5cb9deab407 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9c59937a5a994cf3098af2069041fb4f.setIcon(icon_bd61cf399ffeb71304c9b5cb9deab407);
#
#
#             marker_9c59937a5a994cf3098af2069041fb4f.bindTooltip(
#                 `&lt;div&gt;
#                      0001 10th &amp; Cambie
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_88e43a2381b5dff1542ae99dcc195592 = L.marker(
#                 [49.28645885053061, -123.12102864288579],
#                 {}
#             ).addTo(map_c33d4513e978a53052bb8384b9a312d5);
#
#
#             var icon_5ccc388be84f60ac279200b5d29a9a19 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_88e43a2381b5dff1542ae99dcc195592.setIcon(icon_5ccc388be84f60ac279200b5d29a9a19);
#
#
#             marker_88e43a2381b5dff1542ae99dcc195592.bindTooltip(
#                 `&lt;div&gt;
#                      0002 Burrard Station (Melville &amp; Dunsmuir)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5502f5570e5f0a00fa5fec7692d357fa = L.marker(
#                 [49.2744594, -123.1217156],
#                 {}
#             ).addTo(map_c33d4513e978a53052bb8384b9a312d5);
#
#
#             var icon_774cac79ab5a9b8b4235a1d41dc39e2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5502f5570e5f0a00fa5fec7692d357fa.setIcon(icon_774cac79ab5a9b8b4235a1d41dc39e2f);
#
#
#             marker_5502f5570e5f0a00fa5fec7692d357fa.bindTooltip(
#                 `&lt;div&gt;
#                      0004 Yaletown-Roundhouse Station
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a27ba83953f19c92f830b3c8dfdf0565 = L.marker(
#                 [49.2797102, -123.1100831],
#                 {}
#             ).addTo(map_c33d4513e978a53052bb8384b9a312d5);
#
#
#             var icon_f67464dd28ca5af7dc68ddd0e612c038 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a27ba83953f19c92f830b3c8dfdf

# %%
df.head()
# Out:
#             Departure            Return Electric bike  \
# 0 2023-02-01 00:00:00   2023-02-01 0:00         False
# 1 2023-01-31 23:00:00   2023-02-01 0:00         False
# 2 2023-01-31 23:00:00   2023-02-01 0:00         False
# 3 2023-01-31 23:00:00   2023-02-01 0:00         False
# 4 2023-01-31 23:00:00  2023-01-31 23:00         False
#
#            Departure station              Return station    Membership type  \
# 0        0228 Keefer & Hawks  0232 Britannia Parking Lot     Community Pass
# 1  0035 Hastings & Broughton        0190 Melville & Bute  365 Day Pass Plus
# 2     0058 Richards & Smithe       0071 14th & Granville        30 Day Pass
# 3    0063 Robson & Granville       0030 Abbott & Cordova  365 Day Pass Plus
# 4             0008 8th & Ash         0199 Georgia & Main        30 Day Pass
#
#    Covered distance (m)  Duration (sec.)  Departure temperature (C)  \
# 0                1474.0            515.0                        2.0
# 1               11086.0           3410.0                        3.0
# 2                4318.0           1005.0                        3.0
# 3                3375.0           2221.0                        6.0
# 4                2605.0            473.0                        3.0
#
#    Return temperature (C)  Stopover duration (sec.)  Number of stopovers  \
# 0                     3.0                       0.0                  0.0
# 1                     5.0                     587.0                  1.0
# 2                     6.0                       0.0                  0.0
# 3                     5.0                    1044.0                  5.0
# 4                     5.0                       0.0                  0.0
#
#   Month  Season
# 0   Feb  Winter
# 1   Jan  Winter
# 2   Jan  Winter
# 3   Jan  Winter
# 4   Jan  Winter

# %%
sorted(df['Departure station'].unique())
# Out:
# ['0001 10th & Cambie',
#  '0002 Burrard Station (Melville & Dunsmuir)',
#  '0004 Yaletown-Roundhouse Station',
#  '0005 Dunsmuir & Beatty',
#  '0006 Olympic Village Station',
#  '0007 12th & Yukon (City Hall)',
#  '0008 8th & Ash',
#  '0009 Spyglass & Seawall',
#  '0010 Stamps Landing',
#  '0011 Ontario & Seawall',
#  '0012 Dunsmuir & Richards',
#  '0014 Canada Place',
#  '0015 Granville & Georgia',
#  '0016 Pender & Burrard',
#  '0017 Marinaside & Davie',
#  '0019 Robson & Hornby',
#  '0021 Cordova & Granville',
#  '0024 Hornby & Pender',
#  '0025 Homer & Robson (Vancouver Public Library)',
#  '0026 Beatty & Robson',
#  '0027 Beatty & Nelson',
#  '0028 Davie & Beach',
#  '0030 Abbott & Cordova',
#  '0031 Morton & Denman',
#  '0032 Comox & Denman',
#  '0034 Cordova & Bute',
#  '0035 Hastings & Broughton',
#  '0036 Bute & Robson',
#  '0037 Hornby & Nelson',
#  '0039 Helmcken & Burrard',
#  '0040 Cardero & Davie',
#  '0041 Cardero & Robson',
#  '0044 Pacific & Richards',
#  '0045 Beach & Hornby',
#  '0047 Chilco & Beach',
#  '0048 Comox & Broughton',
#  '0050 Bute & Comox',
#  '0052 Cambie & Water',
#  '0053 Keefer & Abbott',
#  '0054 Expo & Carrall',
#  '0055 Keefer & Columbia',
#  '0057 Marinaside & Cooperage',
#  '0058 Richards & Smithe',
#  '0060 Bidwell & Burnaby',
#  '0063 Robson & Granville',
#  '0064 Expo & Smithe',
#  '0065 Cypress & Cornwall',
#  '0066 Anderson & 2nd',
#  '0068 Cypress & 10th',
#  '0069 7th & Granville',
#  '0070 10th & Granville',
#  '0071 14th & Granville',
#  '0072 14th & Cambie',
#  '0073 Ontario & 5th',
#  '0074 10th & Main',
#  '0075 Arbutus & 10th',
#  '0076 Cypress & 4th',
#  '0077 Vanier Park',
#  '0078 Nelson & Mainland',
#  '0079 Nelson & Richards',
#  '0081 7th & Heather',
#  '0082 Richards & Davie',
#  '0083 Aquatic Centre',
#  '0084 Beach & Broughton',
#  '0087 Broughton & Davie',
#  '0088 Harwood & Bute',
#  '0089 Burrard & Drake',
#  '0092 Chilco & Barclay',
#  '0093 Chilco & Robson',
#  '0096 Nicola & Robson',
#  '0098 Carrall & Hastings',
#  "0099 šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery North Plaza",
#  '0100 Stanley Park - Prospect Point',
#  '0101 Stanley Park - Vancouver Aquarium',
#  '0102 Stanley Park - Second Beach North',
#  '0103 Stanley Park - Third Beach Parking Lot',
#  '0104 Stanley Park - Second Beach South',
#  '0105 Stanley Park - Totem Poles',
#  '0106 Heather & 14th',
#  '0107 8th & Ontario',
#  '0108 1st & Chestnut',
#  '0109 7th & Arbutus',
#  '0110 5th & Arbutus',
#  '0112 10th & Oak',
#  '0113 Arbutus & 16th',
#  '0114 Cypress & 14th',
#  '0115 Cypress & 16th',
#  '0119 3rd & Quebec',
#  '0122 Haro & Denman',
#  '0123 Georgia & Thurlow',
#  '0124 Richards & Cordova',
#  '0126 Thurlow & Pendrell',
#  '0129 Richards & Robson',
#  '0130 Heather & 16th',
#  '0132 14th & Ontario',
#  '0133 Ontario & 16th',
#  '0134 14th & Main',
#  '0136 David Lam Park - West',
#  '0137 Beach & Seymour',
#  '0138 Richards & Helmcken',
#  '0139 Burrard & 4th',
#  '0140 Burrard & 7th',
#  '0142 Beach & Cardero',
#  '0143 South False Creek Seawall',
#  '0144 Wylie & 2nd',
#  '0147 Chestnut & McNicoll',
#  '0148 Creekside Park North',
#  '0150 Alexander & Main',
#  '0152 Arbutus Greenway & 14th',
#  '0153 Arbutus Greenway & Fir',
#  '0155 Arbutus & McNicoll',
#  '0159 Vine & 4th',
#  '0161 Alexander & Dunlevy',
#  '0166 Alder & 11th',
#  '0170 8th & Yukon',
#  '0171 Yukon & 6th',
#  '0172 10th & Columbia',
#  '0173 Columbia & 1st',
#  '0174 1st & Manitoba',
#  '0176 10th & Ontario',
#  '0177 Quebec & 1st',
#  '0179 11th & Kingsway',
#  '0180 Columbia & 14th',
#  '0186 10th & Kingsway',
#  '0187 Bute & Davie',
#  '0189 Granville Island',
#  '0190 Melville & Bute',
#  '0191 7th & Laurel',
#  '0192 7th &  Alder',
#  '0193 Science World',
#  '0196 Hornby & Drake',
#  '0197 1st & Scotia',
#  '0198 5th & Main',
#  '0199 Georgia & Main',
#  '0200 Cardero & Bayshore',
#  '0201 Shaw Tower',
#  '0202 14th & Oak',
#  '0203 Pine & 14th',
#  '0204 York & Yew',
#  '0205 Pine & 10th',
#  '0206 8th & Scotia',
#  '0207 Alberni & Jervis',
#  '0209 Stanley Park - Information Booth',
#  '0210 Burrard & 14th',
#  '0211 14th & Alder',
#  '0212 Union & Dunlevy',
#  '0213 Pender & Gore',
#  '0215 Princess & Union',
#  '0217 Smithe & Burrard',
#  '0218 Carrall & Seawall',
#  '0219 Hawks & Union',
#  '0221 Glen & Union',
#  '0222 Adanac & McLean',
#  '0223 Commercial & Adanac',
#  '0224 Pender & Commercial',
#  '0225 McLean & Pender',
#  '0227 Campbell & Hastings',
#  '0228 Keefer & Hawks',
#  '0229 Keefer & Princess',
#  '0230 Alexander & Railway',
#  '0231 Napier & Commercial',
#  '0232 Britannia Parking Lot',
#  '0233 Thornton & National',
#  '0235 Charles & Commercial',
#  '0236 Keith & 6th',
#  '0237 Glen & 6th',
#  '0239 Grant & Commercial',
#  '0240 2nd & Commercial',
#  '0241 4th & Commercial',
#  '0242 8th & Commercial',
#  '0244 10th & Commercial',
#  '0245 Woodland & 10th',
#  '0246 Glen & Broadway',
#  '0248 St George & Broadway',
#  '0249 7th & Woodland',
#  '0250 Woodland & 4th',
#  '0252 Woodland & Graveley',
#  '0253 Charles & Woodland',
#  '0254 Grandview & Commercial',
#  '0255 18th & Main',
#  '0256 Prince Edward & 16th',
#  '0257 Prince Edward & 14th',
#  '0258 13th & St George',
#  '0260 10th & Fraser',
#  '0261 8th & Fraser',
#  '0262 8th & Prince Edward',
#  '0265 St Catherines & 10th',
#  '0266 St Catherines & 7th',
#  '0272 Pender & Victoria',
#  '0273 Victoria & 4th',
#  '0274 Victoria & 10th',
#  '0278 15th & Victoria (Trout Lake)',
#  '0280 Triumph & Victoria',
#  '0281 Windsor & 14th',
#  '0282 14th & Fraser',
#  '0283 15th & Knight',
#  '0285 Commercial & Pandora',
#  '0287 Carolina & Great Northern Way',
#  '0297 6th & Prince Edward',
#  '0298 6th & Carolina',
#  '0300 Bute & Barclay',
#  '0305 Georgia & Homer',
#  '0308 Seymour & Cordova',
#  '0310 Jervis & Robson',
#  '0311 13th & Cambie',
#  '0313 Nelson & Denman',
#  '0314 Rolston & Granville',
#  '0315 1st & Fir',
#  '0352 Commercial & 20th',
#  '0354 Station & Terminal',
#  '0400 Jericho Beach',
#  '0401 Wallace & 4th',
#  '0403 Highbury & 8th',
#  '0410 Alma & Point Grey',
#  '0414 Dunbar & 6th',
#  '0415 Dunbar & Broadway',
#  '0431 Blenheim & 4th',
#  '0440 Point Grey & Blenheim',
#  '0443 Balaclava & 6th',
#  '0444 Balaclava & Broadway',
#  '0450 Point Grey & Bayswater',
#  '0452 8th & Macdonald',
#  '0460 Trafalgar & Cornwall',
#  '0464 Trafalgar & Broadway',
#  '0470 Balsam & Cornwall',
#  '0480 Arbutus & Nanton',
#  '0482 East Blvd & 37th',
#  '0484 Yew & Broadway',
#  '0505 28th & Willow',
#  '0511 18th & Heather',
#  '0516 Heather & 29th',
#  '0524 King Edward & Cambie',
#  '0526 29th & Cambie',
#  '0531 18th & Cambie',
#  '0532 22nd & Cambie',
#  '0554 Ontario & 23rd',
#  '0557 30th & Ontario',
#  '0561 20th & Main',
#  '0563 22nd & Main',
#  '0565 27th & Main',
#  '0611 Wall & Eton',
#  '0621 Lakewood & Oxford',
#  '0631 Lakewood & Triumph',
#  '0642 Franklin & Nanaimo',
#  '0715 Trimble & 8th',
#  '0716 Sasamat & 10th',
#  '1002 PNE - Hastings & Windermere',
#  '2132 IK Barber Learning Centre',
#  '2143 War Memorial Gym',
#  '2156 Pharmaceutical Sciences']

# %%
df.groupby(['Departure station', 'Month'])['Electric bike'].count()
# Out:
# Departure station             Month
# 0001 10th & Cambie            Apr       577
#                               Aug      1347
#                               Dec       588
#                               Feb       472
#                               Jan       978
#                                        ...
# 2143 War Memorial Gym         Dec        47
#                               Jan        68
#                               Nov         2
# 2156 Pharmaceutical Sciences  Dec        68
#                               Jan        20
# Name: Electric bike, Length: 2905, dtype: int64

# %%
df.groupby(['Return station', 'Month'])['Departure'].count()
# Out:
# Return station                Month
# 0001 10th & Cambie            Apr       766
#                               Aug      1358
#                               Dec       738
#                               Feb       582
#                               Jan      1188
#                                        ...
# 2143 War Memorial Gym         Jan        60
#                               Nov         2
# 2156 Pharmaceutical Sciences  Dec        60
#                               Jan        30
#                               Nov         2
# Name: Departure, Length: 2907, dtype: int64

# %%
departure_counts = df.groupby(['Departure station', 'Month']).agg({'Electric bike': 'count'}).reset_index()
return_counts = df.groupby(['Return station', 'Month']).agg({'Electric bike': 'count'}).reset_index()

# Rename columns for clarity
departure_counts.columns = ['Station', 'Month', 'Departure Count']
return_counts.columns = ['Station', 'Month', 'Return Count']

# Merge the two DataFrames on Station and Month
combined_counts = pd.merge(departure_counts, return_counts, on=['Station', 'Month'], how='outer').fillna(0)
combined_counts['Total Count'] = combined_counts['Departure Count'] + combined_counts['Return Count']

# %%
combined_counts.drop(['Departure Count', 'Return Count'], axis = 1, inplace = True)

# %%
combined_counts
# Out:
#                            Station Month  Total Count
# 0               0001 10th & Cambie   Apr       1343.0
# 1               0001 10th & Cambie   Aug       2705.0
# 2               0001 10th & Cambie   Dec       1326.0
# 3               0001 10th & Cambie   Feb       1054.0
# 4               0001 10th & Cambie   Jan       2166.0
# ...                            ...   ...          ...
# 2903  2156 Pharmaceutical Sciences   Dec        128.0
# 2904  2156 Pharmaceutical Sciences   Jan         50.0
# 2905            0715 Trimble & 8th   Aug          2.0
# 2906           0716 Sasamat & 10th   Aug          3.0
# 2907  2156 Pharmaceutical Sciences   Nov          2.0
#
# [2908 rows x 3 columns]

# %%
df2 = pd.merge(combined_counts, dfc, on = ['Station'])

# %%
total_counts_by_station = df2.groupby(['Station'])['Total Count'].sum()
total_counts_by_station
# Out:
# Station
# 0001 10th & Cambie                            23287.0
# 0002 Burrard Station (Melville & Dunsmuir)    17527.0
# 0004 Yaletown-Roundhouse Station              19472.0
# 0005 Dunsmuir & Beatty                        25178.0
# 0006 Olympic Village Station                  23847.0
#                                                ...
# 0716 Sasamat & 10th                             547.0
# 1002 PNE - Hastings & Windermere               1200.0
# 2132 IK Barber Learning Centre                  160.0
# 2143 War Memorial Gym                           233.0
# 2156 Pharmaceutical Sciences                    180.0
# Name: Total Count, Length: 250, dtype: float64

# %%
total_counts_by_station = df2.groupby(['Station', 'Coordinates', 'Month'])['Total Count'].sum().reset_index(name='Total Count')
total_counts_by_station
# Out:
#                            Station                              Coordinates  \
# 0               0001 10th & Cambie               (49.2622822, -123.1142145)
# 1               0001 10th & Cambie               (49.2622822, -123.1142145)
# 2               0001 10th & Cambie               (49.2622822, -123.1142145)
# 3               0001 10th & Cambie               (49.2622822, -123.1142145)
# 4               0001 10th & Cambie               (49.2622822, -123.1142145)
# ...                            ...                                      ...
# 2903         2143 War Memorial Gym         (49.266796, -123.24763482487361)
# 2904         2143 War Memorial Gym         (49.266796, -123.24763482487361)
# 2905  2156 Pharmaceutical Sciences  (49.26474842889402, -123.2430141715432)
# 2906  2156 Pharmaceutical Sciences  (49.26474842889402, -123.2430141715432)
# 2907  2156 Pharmaceutical Sciences  (49.26474842889402, -123.2430141715432)
#
#      Month  Total Count
# 0      Apr       1343.0
# 1      Aug       2705.0
# 2      Dec       1326.0
# 3      Feb       1054.0
# 4      Jan       2166.0
# ...    ...          ...
# 2903   Jan        128.0
# 2904   Nov          4.0
# 2905   Dec        128.0
# 2906   Jan         50.0
# 2907   Nov          2.0
#
# [2908 rows x 4 columns]

# %%
marker_locations = total_counts_by_station.to_dict(orient='records')

for entry in marker_locations:
    entry['Coordinates'] = tuple(map(float, entry['Coordinates'].strip('()').split(', ')))

marker_locations
# Out:
# [{'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Apr',
#   'Total Count': 1343.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Aug',
#   'Total Count': 2705.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Dec',
#   'Total Count': 1326.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Feb',
#   'Total Count': 1054.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Jan',
#   'Total Count': 2166.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Jul',
#   'Total Count': 2533.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Jun',
#   'Total Count': 2269.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Mar',
#   'Total Count': 1461.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'May',
#   'Total Count': 2279.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Nov',
#   'Total Count': 1713.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Oct',
#   'Total Count': 2087.0},
#  {'Station': '0001 10th & Cambie',
#   'Coordinates': (49.2622822, -123.1142145),
#   'Month': 'Sep',
#   'Total Count': 2351.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Apr',
#   'Total Count': 917.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Aug',
#   'Total Count': 2201.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Dec',
#   'Total Count': 949.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Feb',
#   'Total Count': 729.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Jan',
#   'Total Count': 1507.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Jul',
#   'Total Count': 2311.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Jun',
#   'Total Count': 1846.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Mar',
#   'Total Count': 1066.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'May',
#   'Total Count': 1661.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Nov',
#   'Total Count': 1128.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Oct',
#   'Total Count': 1338.0},
#  {'Station': '0002 Burrard Station (Melville & Dunsmuir)',
#   'Coordinates': (49.28645885053061, -123.12102864288579),
#   'Month': 'Sep',
#   'Total Count': 1874.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Apr',
#   'Total Count': 982.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Aug',
#   'Total Count': 2582.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Dec',
#   'Total Count': 1016.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Feb',
#   'Total Count': 651.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Jan',
#   'Total Count': 1349.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Jul',
#   'Total Count': 2500.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Jun',
#   'Total Count': 2126.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Mar',
#   'Total Count': 999.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'May',
#   'Total Count': 1772.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Nov',
#   'Total Count': 1525.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Oct',
#   'Total Count': 1730.0},
#  {'Station': '0004 Yaletown-Roundhouse Station',
#   'Coordinates': (49.2744594, -123.1217156),
#   'Month': 'Sep',
#   'Total Count': 2240.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Apr',
#   'Total Count': 1299.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Aug',
#   'Total Count': 3051.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Dec',
#   'Total Count': 1349.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Feb',
#   'Total Count': 1048.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Jan',
#   'Total Count': 2298.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Jul',
#   'Total Count': 2743.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Jun',
#   'Total Count': 2452.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Mar',
#   'Total Count': 1579.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'May',
#   'Total Count': 2349.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Nov',
#   'Total Count': 1909.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Oct',
#   'Total Count': 2286.0},
#  {'Station': '0005 Dunsmuir & Beatty',
#   'Coordinates': (49.2797102, -123.1100831),
#   'Month': 'Sep',
#   'Total Count': 2815.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Apr',
#   'Total Count': 1311.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Aug',
#   'Total Count': 2827.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Dec',
#   'Total Count': 1229.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Feb',
#   'Total Count': 930.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Jan',
#   'Total Count': 1942.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Jul',
#   'Total Count': 2913.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Jun',
#   'Total Count': 2561.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Mar',
#   'Total Count': 1515.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'May',
#   'Total Count': 2398.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Nov',
#   'Total Count': 1656.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Oct',
#   'Total Count': 2078.0},
#  {'Station': '0006 Olympic Village Station',
#   'Coordinates': (49.2665609, -123.1156986),
#   'Month': 'Sep',
#   'Total Count': 2487.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Apr',
#   'Total Count': 216.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Aug',
#   'Total Count': 365.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Dec',
#   'Total Count': 158.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Feb',
#   'Total Count': 144.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Jan',
#   'Total Count': 280.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Jul',
#   'Total Count': 390.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Jun',
#   'Total Count': 333.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Mar',
#   'Total Count': 193.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'May',
#   'Total Count': 268.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Nov',
#   'Total Count': 242.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Oct',
#   'Total Count': 289.0},
#  {'Station': '0007 12th & Yukon (City Hall)',
#   'Coordinates': (49.261869270826644, -123.1142389387551),
#   'Month': 'Sep',
#   'Total Count': 284.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Apr',
#   'Total Count': 666.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Aug',
#   'Total Count': 1450.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Dec',
#   'Total Count': 629.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Feb',
#   'Total Count': 561.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Jan',
#   'Total Count': 1131.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Jul',
#   'Total Count': 1447.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Jun',
#   'Total Count': 1227.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Mar',
#   'Total Count': 739.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'May',
#   'Total Count': 1031.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Nov',
#   'Total Count': 836.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Oct',
#   'Total Count': 951.0},
#  {'Station': '0008 8th & Ash',
#   'Coordinates': (49.2642151, -123.1178195),
#   'Month': 'Sep',
#   'Total Count': 1292.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Apr',
#   'Total Count': 624.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Aug',
#   'Total Count': 1796.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Dec',
#   'Total Count': 293.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Feb',
#   'Total Count': 329.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Jan',
#   'Total Count': 624.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Jul',
#   'Total Count': 1778.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Jun',
#   'Total Count': 1494.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Mar',
#   'Total Count': 564.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'May',
#   'Total Count': 1239.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Nov',
#   'Total Count': 434.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Oct',
#   'Total Count': 782.0},
#  {'Station': '0009 Spyglass & Seawall',
#   'Coordinates': (49.270861, -123.1150229),
#   'Month': 'Sep',
#   'Total Count': 1402.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Apr',
#   'Total Count': 650.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Aug',
#   'Total Count': 1753.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Dec',
#   'Total Count': 413.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Feb',
#   'Total Count': 320.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Jan',
#   'Total Count': 618.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Jul',
#   'Total Count': 2104.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Jun',
#   'Total Count': 1481.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Mar',
#   'Total Count': 575.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'May',
#   'Total Count': 1421.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Nov',
#   'Total Count': 488.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Oct',
#   'Total Count': 922.0},
#  {'Station': '0010 Stamps Landing',
#   'Coordinates': (49.2686127, -123.1180201),
#   'Month': 'Sep',
#   'Total Count': 1375.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Apr',
#   'Total Count': 1639.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Aug',
#   'Total Count': 4627.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Dec',
#   'Total Count': 1104.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Feb',
#   'Total Count': 950.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Jan',
#   'Total Count': 1966.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Jul',
#   'Total Count': 4710.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Jun',
#   'Total Count': 3402.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Mar',
#   'Total Count': 1698.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'May',
#   'Total Count': 3082.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Nov',
#   'Total Count': 1634.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Oct',
#   'Total Count': 2367.0},
#  {'Station': '0011 Ontario & Seawall',
#   'Coordinates': (49.2716914, -123.1042968),
#   'Month': 'Sep',
#   'Total Count': 3516.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Apr',
#   'Total Count': 1294.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Aug',
#   'Total Count': 2669.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Dec',
#   'Total Count': 1034.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Feb',
#   'Total Count': 823.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Jan',
#   'Total Count': 1838.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Jul',
#   'Total Count': 2522.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Jun',
#   'Total Count': 2152.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Mar',
#   'Total Count': 1201.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'May',
#   'Total Count': 1965.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Nov',
#   'Total Count': 1582.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Oct',
#   'Total Count': 2022.0},
#  {'Station': '0012 Dunsmuir & Richards',
#   'Coordinates': (49.282223, -123.11418428602579),
#   'Month': 'Sep',
#   'Total Count': 2167.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Apr',
#   'Total Count': 1756.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Aug',
#   'Total Count': 4127.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Dec',
#   'Total Count': 1197.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Feb',
#   'Total Count': 784.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Jan',
#   'Total Count': 1598.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Jul',
#   'Total Count': 4175.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Jun',
#   'Total Count': 3485.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Mar',
#   'Total Count': 1503.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'May',
#   'Total Count': 2941.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Nov',
#   'Total Count': 1249.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Oct',
#   'Total Count': 2191.0},
#  {'Station': '0014 Canada Place',
#   'Coordinates': (49.287388922756584, -123.11289146009278),
#   'Month': 'Sep',
#   'Total Count': 3390.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Apr',
#   'Total Count': 636.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Aug',
#   'Total Count': 1820.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Dec',
#   'Total Count': 811.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Feb',
#   'Total Count': 709.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Jan',
#   'Total Count': 1284.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Jul',
#   'Total Count': 1916.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Jun',
#   'Total Count': 1561.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Mar',
#   'Total Count': 728.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'May',
#   'Total Count': 1278.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Nov',
#   'Total Count': 930.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Oct',
#   'Total Count': 1060.0},
#  {'Station': '0015 Granville & Georgia',
#   'Coordinates': (49.28344610167394, -123.11835460013414),
#   'Month': 'Sep',
#   'Total Count': 1495.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Apr',
#   'Total Count': 526.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Aug',
#   'Total Count': 1208.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Dec',
#   'Total Count': 430.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Feb',
#   'Total Count': 236.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Jan',
#   'Total Count': 787.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Jul',
#   'Total Count': 1333.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Jun',
#   'Total Count': 1170.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Mar',
#   'Total Count': 585.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'May',
#   'Total Count': 858.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Nov',
#   'Total Count': 697.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Oct',
#   'Total Count': 740.0},
#  {'Station': '0016 Pender & Burrard',
#   'Coordinates': (49.2871315, -123.1186171),
#   'Month': 'Sep',
#   'Total Count': 1095.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Apr',
#   'Total Count': 1256.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Aug',
#   'Total Count': 3482.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Dec',
#   'Total Count': 828.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Feb',
#   'Total Count': 738.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Jan',
#   'Total Count': 1478.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Jul',
#   'Total Count': 3844.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Jun',
#   'Total Count': 2677.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Mar',
#   'Total Count': 1224.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'May',
#   'Total Count': 2630.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Nov',
#   'Total Count': 1196.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Oct',
#   'Total Count': 1906.0},
#  {'Station': '0017 Marinaside & Davie',
#   'Coordinates': (49.2735635, -123.1179519),
#   'Month': 'Sep',
#   'Total Count': 2818.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Apr',
#   'Total Count': 825.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Aug',
#   'Total Count': 2604.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Dec',
#   'Total Count': 932.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Feb',
#   'Total Count': 630.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Jan',
#   'Total Count': 1323.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Jul',
#   'Total Count': 2641.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Jun',
#   'Total Count': 1881.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Mar',
#   'Total Count': 846.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'May',
#   'Total Count': 1473.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Nov',
#   'Total Count': 1125.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Oct',
#   'Total Count': 1591.0},
#  {'Station': '0019 Robson & Hornby',
#   'Coordinates': (49.2827328, -123.1220614),
#   'Month': 'Sep',
#   'Total Count': 2055.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Apr',
#   'Total Count': 354.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Aug',
#   'Total Count': 1326.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Dec',
#   'Total Count': 381.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Feb',
#   'Total Count': 317.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Jan',
#   'Total Count': 757.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Jul',
#   'Total Count': 1250.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Jun',
#   'Total Count': 827.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Mar',
#   'Total Count': 233.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'May',
#   'Total Count': 504.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Nov',
#   'Total Count': 480.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Oct',
#   'Total Count': 703.0},
#  {'Station': '0021 Cordova & Granville',
#   'Coordinates': (49.285583, -123.1126026),
#   'Month': 'Sep',
#   'Total Count': 1013.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Apr',
#   'Total Count': 1296.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Aug',
#   'Total Count': 3165.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Dec',
#   'Total Count': 1236.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Feb',
#   'Total Count': 914.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Jan',
#   'Total Count': 1966.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Jul',
#   'Total Count': 3078.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Jun',
#   'Total Count': 2513.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Mar',
#   'Total Count': 1387.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'May',
#   'Total Count': 2396.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Nov',
#   'Total Count': 1923.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Oct',
#   'Total Count': 2126.0},
#  {'Station': '0024 Hornby & Pender',
#   'Coordinates': (49.2860026, -123.116602),
#   'Month': 'Sep',
#   'Total Count': 2849.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Apr',
#   'Total Count': 560.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Aug',
#   'Total Count': 1181.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Dec',
#   'Total Count': 711.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Feb',
#   'Total Count': 468.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Jan',
#   'Total Count': 1001.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Jul',
#   'Total Count': 1454.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Jun',
#   'Total Count': 1063.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Mar',
#   'Total Count': 656.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'May',
#   'Total Count': 1005.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Nov',
#   'Total Count': 967.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Oct',
#   'Total Count': 1168.0},
#  {'Station': '0025 Homer & Robson (Vancouver Public Library)',
#   'Coordinates': (49.28002846068264, -123.11613989355355),
#   'Month': 'Sep',
#   'Total Count': 1261.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Apr',
#   'Total Count': 698.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Aug',
#   'Total Count': 1826.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Dec',
#   'Total Count': 279.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Feb',
#   'Total Count': 584.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Jan',
#   'Total Count': 920.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Jul',
#   'Total Count': 1888.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Jun',
#   'Total Count': 1509.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Mar',
#   'Total Count': 708.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'May',
#   'Total Count': 1314.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Nov',
#   'Total Count': 222.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Oct',
#   'Total Count': 1252.0},
#  {'Station': '0026 Beatty & Robson',
#   'Coordinates': (49.2774968, -123.114236),
#   'Month': 'Sep',
#   'Total Count': 1562.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Apr',
#   'Total Count': 342.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Aug',
#   'Total Count': 1326.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Dec',
#   'Total Count': 385.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Feb',
#   'Total Count': 289.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Jan',
#   'Total Count': 578.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Jul',
#   'Total Count': 1246.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Jun',
#   'Total Count': 938.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Mar',
#   'Total Count': 450.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'May',
#   'Total Count': 845.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Nov',
#   'Total Count': 552.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Oct',
#   'Total Count': 753.0},
#  {'Station': '0027 Beatty & Nelson',
#   'Coordinates': (49.275649, -123.1170024),
#   'Month': 'Sep',
#   'Total Count': 1097.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Apr',
#   'Total Count': 3044.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Aug',
#   'Total Count': 7579.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Dec',
#   'Total Count': 1516.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Feb',
#   'Total Count': 1289.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Jan',
#   'Total Count': 2515.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Jul',
#   'Total Count': 5294.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Jun',
#   'Total Count': 7173.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Mar',
#   'Total Count': 2676.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'May',
#   'Total Count': 5947.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Nov',
#   'Total Count': 1995.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Oct',
#   'Total Count': 4099.0},
#  {'Station': '0028 Davie & Beach',
#   'Coordinates': (49.2875014, -123.1420991),
#   'Month': 'Sep',
#   'Total Count': 6737.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Apr',
#   'Total Count': 1115.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Aug',
#   'Total Count': 2419.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Dec',
#   'Total Count': 919.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Feb',
#   'Total Count': 805.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Jan',
#   'Total Count': 1723.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Jul',
#   'Total Count': 2816.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Jun',
#   'Total Count': 2239.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Mar',
#   'Total Count': 1091.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'May',
#   'Total Count': 1801.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Nov',
#   'Total Count': 1483.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Oct',
#   'Total Count': 1885.0},
#  {'Station': '0030 Abbott & Cordova',
#   'Coordinates': (49.2826816, -123.107005),
#   'Month': 'Sep',
#   'Total Count': 2145.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Apr',
#   'Total Count': 1380.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Aug',
#   'Total Count': 3433.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Dec',
#   'Total Count': 631.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Feb',
#   'Total Count': 624.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Jan',
#   'Total Count': 1185.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Jul',
#   'Total Count': 2422.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Jun',
#   'Total Count': 3343.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Mar',
#   'Total Count': 1254.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'May',
#   'Total Count': 3074.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Nov',
#   'Total Count': 798.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Oct',
#   'Total Count': 1633.0},
#  {'Station': '0031 Morton & Denman',
#   'Coordinates': (49.2880013, -123.1420794),
#   'Month': 'Sep',
#   'Total Count': 2615.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Apr',
#   'Total Count': 940.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Aug',
#   'Total Count': 2181.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Dec',
#   'Total Count': 768.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Feb',
#   'Total Count': 617.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Jan',
#   'Total Count': 1286.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Jul',
#   'Total Count': 2852.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Jun',
#   'Total Count': 1699.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Mar',
#   'Total Count': 901.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'May',
#   'Total Count': 1506.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Nov',
#   'Total Count': 1071.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Oct',
#   'Total Count': 1355.0},
#  {'Station': '0032 Comox & Denman',
#   'Coordinates': (49.2885183, -123.1393327),
#   'Month': 'Sep',
#   'Total Count': 1762.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Apr',
#   'Total Count': 746.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Aug',
#   'Total Count': 1490.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Dec',
#   'Total Count': 421.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Feb',
#   'Total Count': 288.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Jan',
#   'Total Count': 626.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Jul',
#   'Total Count': 1777.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Jun',
#   'Total Count': 1469.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Mar',
#   'Total Count': 670.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'May',
#   'Total Count': 1337.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Nov',
#   'Total Count': 571.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Oct',
#   'Total Count': 813.0},
#  {'Station': '0034 Cordova & Bute',
#   'Coordinates': (49.2890985, -123.121827),
#   'Month': 'Sep',
#   'Total Count': 1263.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Apr',
#   'Total Count': 1140.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Aug',
#   'Total Count': 1774.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Dec',
#   'Total Count': 548.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Feb',
#   'Total Count': 609.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Jan',
#   'Total Count': 1092.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Jul',
#   'Total Count': 2067.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Jun',
#   'Total Count': 1583.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Mar',
#   'Total Count': 945.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'May',
#   'Total Count': 1781.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Nov',
#   'Total Count': 694.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Oct',
#   'Total Count': 968.0},
#  {'Station': '0035 Hastings & Broughton',
#   'Coordinates': (49.2901111, -123.12703),
#   'Month': 'Sep',
#   'Total Count': 1507.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Apr',
#   'Total Count': 1104.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Aug',
#   'Total Count': 3023.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Dec',
#   'Total Count': 1234.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Feb',
#   'Total Count': 863.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Jan',
#   'Total Count': 1728.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Jul',
#   'Total Count': 3019.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Jun',
#   'Total Count': 2380.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Mar',
#   'Total Count': 1075.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'May',
#   'Total Count': 2039.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Nov',
#   'Total Count': 1496.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Oct',
#   'Total Count': 1846.0},
#  {'Station': '0036 Bute & Robson',
#   'Coordinates': (49.2858689, -123.1272595),
#   'Month': 'Sep',
#   'Total Count': 2453.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Apr',
#   'Total Count': 1136.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Aug',
#   'Total Count': 2263.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Dec',
#   'Total Count': 868.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Feb',
#   'Total Count': 674.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Jan',
#   'Total Count': 1369.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Jul',
#   'Total Count': 2706.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Jun',
#   'Total Count': 2089.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Mar',
#   'Total Count': 800.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'May',
#   'Total Count': 1800.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Nov',
#   'Total Count': 1224.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Oct',
#   'Total Count': 1682.0},
#  {'Station': '0037 Hornby & Nelson',
#   'Coordinates': (49.2806129, -123.12478),
#   'Month': 'Sep',
#   'Total Count': 2148.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Apr',
#   'Total Count': 963.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Aug',
#   'Total Count': 2508.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Dec',
#   'Total Count': 1054.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Feb',
#   'Total Count': 843.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Jan',
#   'Total Count': 1603.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Jul',
#   'Total Count': 2410.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Jun',
#   'Total Count': 1968.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Mar',
#   'Total Count': 1354.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'May',
#   'Total Count': 1921.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Nov',
#   'Total Count': 1096.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Oct',
#   'Total Count': 1435.0},
#  {'Station': '0039 Helmcken & Burrard',
#   'Coordinates': (49.2799185, -123.1274469),
#   'Month': 'Sep',
#   'Total Count': 1963.0},
#  {'Station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385),
#   'Month': 'Apr',
#   'Total Count': 1059.0},
#  {'Station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385),
#   'Month': 'Aug',
#   'Total Count': 2418.0},
#  {'Station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385),
#   'Month': 'Dec',
#   'Total Count': 978.0},
#  {'Station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385),
#   'Month': 'Feb',
#   'Total Count': 695.0},
#  {'Station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385),
#   'Month': 'Jan',
#   'Total Count': 1438.0},
#  {'Station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385),
#   'Month': 'Jul',
#   'Total Count': 2825.0},
#  {'Station': '0040 Cardero & Davie',
#   'Coordinates': (49.2855326, -123.138385),
#   'Month': 'Jun',
#   'Total Count': 2155.0},
# ...
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Feb',
#   'Total Count': 1033.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Jan',
#   'Total Count': 1751.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Jul',
#   'Total Count': 9662.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Jun',
#   'Total Count': 6207.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Mar',
#   'Total Count': 2241.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'May',
#   'Total Count': 5009.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Nov',
#   'Total Count': 1288.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Oct',
#   'Total Count': 2918.0},
#  {'Station': '0102 Stanley Park - Second Beach North',
#   'Coordinates': (49.296039686859736, -123.15058320425774),
#   'Month': 'Sep',
#   'Total Count': 5601.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Apr',
#   'Total Count': 2058.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Aug',
#   'Total Count': 8071.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Dec',
#   'Total Count': 752.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Feb',
#   'Total Count': 633.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Jan',
#   'Total Count': 1374.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Jul',
#   'Total Count': 8839.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Jun',
#   'Total Count': 5712.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Mar',
#   'Total Count': 1441.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'May',
#   'Total Count': 5103.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Nov',
#   'Total Count': 1236.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Oct',
#   'Total Count': 2863.0},
#  {'Station': '0103 Stanley Park - Third Beach Parking Lot',
#   'Coordinates': (49.3026103, -123.1556398),
#   'Month': 'Sep',
#   'Total Count': 5436.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Apr',
#   'Total Count': 2235.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Aug',
#   'Total Count': 5882.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Dec',
#   'Total Count': 840.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Feb',
#   'Total Count': 908.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Jan',
#   'Total Count': 1321.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Jul',
#   'Total Count': 6771.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Jun',
#   'Total Count': 4724.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Mar',
#   'Total Count': 1861.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'May',
#   'Total Count': 3554.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Nov',
#   'Total Count': 1179.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Oct',
#   'Total Count': 2599.0},
#  {'Station': '0104 Stanley Park - Second Beach South',
#   'Coordinates': (49.297539522369085, -123.14898441664901),
#   'Month': 'Sep',
#   'Total Count': 4493.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Apr',
#   'Total Count': 2516.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Aug',
#   'Total Count': 6778.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Dec',
#   'Total Count': 1259.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Feb',
#   'Total Count': 1316.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Jan',
#   'Total Count': 2293.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Jul',
#   'Total Count': 7109.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Jun',
#   'Total Count': 5751.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Mar',
#   'Total Count': 2441.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'May',
#   'Total Count': 4863.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Nov',
#   'Total Count': 1636.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Oct',
#   'Total Count': 3210.0},
#  {'Station': '0105 Stanley Park - Totem Poles',
#   'Coordinates': (49.29923738044803, -123.12144447937625),
#   'Month': 'Sep',
#   'Total Count': 5735.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Apr',
#   'Total Count': 381.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Aug',
#   'Total Count': 1022.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Dec',
#   'Total Count': 459.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Feb',
#   'Total Count': 288.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Jan',
#   'Total Count': 632.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Jul',
#   'Total Count': 920.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Jun',
#   'Total Count': 833.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Mar',
#   'Total Count': 405.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'May',
#   'Total Count': 761.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Nov',
#   'Total Count': 653.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Oct',
#   'Total Count': 857.0},
#  {'Station': '0106 Heather & 14th',
#   'Coordinates': (49.260101240659985, -123.12033857934635),
#   'Month': 'Sep',
#   'Total Count': 919.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Apr',
#   'Total Count': 491.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Aug',
#   'Total Count': 1344.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Dec',
#   'Total Count': 560.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Feb',
#   'Total Count': 292.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Jan',
#   'Total Count': 638.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Jul',
#   'Total Count': 1325.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Jun',
#   'Total Count': 1082.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Mar',
#   'Total Count': 512.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'May',
#   'Total Count': 988.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Nov',
#   'Total Count': 758.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Oct',
#   'Total Count': 825.0},
#  {'Station': '0107 8th & Ontario',
#   'Coordinates': (49.264031774991814, -123.1052244285798),
#   'Month': 'Sep',
#   'Total Count': 1099.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Apr',
#   'Total Count': 905.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Aug',
#   'Total Count': 2101.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Dec',
#   'Total Count': 672.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Feb',
#   'Total Count': 632.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Jan',
#   'Total Count': 1184.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Jul',
#   'Total Count': 2224.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Jun',
#   'Total Count': 1841.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Mar',
#   'Total Count': 1029.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'May',
#   'Total Count': 1607.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Nov',
#   'Total Count': 946.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Oct',
#   'Total Count': 1331.0},
#  {'Station': '0108 1st & Chestnut',
#   'Coordinates': (49.2707276, -123.1461997),
#   'Month': 'Sep',
#   'Total Count': 1756.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Apr',
#   'Total Count': 287.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Aug',
#   'Total Count': 787.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Dec',
#   'Total Count': 263.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Feb',
#   'Total Count': 166.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Jan',
#   'Total Count': 367.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Jul',
#   'Total Count': 844.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Jun',
#   'Total Count': 571.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Mar',
#   'Total Count': 253.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'May',
#   'Total Count': 453.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Nov',
#   'Total Count': 378.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Oct',
#   'Total Count': 442.0},
#  {'Station': '0109 7th & Arbutus',
#   'Coordinates': (49.2656102, -123.1525342),
#   'Month': 'Sep',
#   'Total Count': 599.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Apr',
#   'Total Count': 385.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Aug',
#   'Total Count': 878.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Dec',
#   'Total Count': 339.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Feb',
#   'Total Count': 227.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Jan',
#   'Total Count': 508.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Jul',
#   'Total Count': 1102.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Jun',
#   'Total Count': 741.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Mar',
#   'Total Count': 303.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'May',
#   'Total Count': 657.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Nov',
#   'Total Count': 385.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Oct',
#   'Total Count': 530.0},
#  {'Station': '0110 5th & Arbutus',
#   'Coordinates': (49.267233, -123.1531863),
#   'Month': 'Sep',
#   'Total Count': 664.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Apr',
#   'Total Count': 815.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Aug',
#   'Total Count': 1620.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Dec',
#   'Total Count': 679.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Feb',
#   'Total Count': 558.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Jan',
#   'Total Count': 1168.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Jul',
#   'Total Count': 1665.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Jun',
#   'Total Count': 1287.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Mar',
#   'Total Count': 740.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'May',
#   'Total Count': 1277.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Nov',
#   'Total Count': 859.0},
#  {'Station': '0112 10th & Oak',
#   'Coordinates': (49.2622734, -123.12616),
#   'Month': 'Oct',
#   'Total Count': 1122.0},
#  ...]

# %%
import folium

# Define the GeoJSON feature object for Vancouver boundary
vancouver_geojson = {
    "type": "Feature",
    "properties": {
        "name": "Vancouver",
        "description": "Boundary of the city of Vancouver, British Columbia, Canada"
    }
}

# Create a Folium map centered around Vancouver
map_vancouver = folium.Map(location=[49.2827, -123.1207], zoom_start=12)

# Add GeoJSON boundary to the map
folium.GeoJson(vancouver_geojson).add_to(map_vancouver)

# Add markers to specific locations
for item in marker_locations:
    location = item["Coordinates"]
    name = item["Station"]
    info = int(item["Total Count"])
    folium.Marker(
        location=location,
        icon=folium.Icon(icon='bicycle', prefix='fa', color='red'),
        tooltip=f"{name}: {info}"
    ).add_to(map_vancouver)

# Display the map
map_vancouver
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02bde57d7a8fb99976d2d659a6078228 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02bde57d7a8fb99976d2d659a6078228&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02bde57d7a8fb99976d2d659a6078228 = L.map(
#                 &quot;map_02bde57d7a8fb99976d2d659a6078228&quot;,
#                 {
#                     center: [49.2827, -123.1207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddcdc0be314bc65191b51feb684f1cc0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ddcdc0be314bc65191b51feb684f1cc0.addTo(map_02bde57d7a8fb99976d2d659a6078228);
#
#
#
#         function geo_json_1cf824e66837b819cf43b3b8229dd656_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1cf824e66837b819cf43b3b8229dd656 = L.geoJson(null, {
#                 onEachFeature: geo_json_1cf824e66837b819cf43b3b8229dd656_onEachFeature,
#
#         });
#
#         function geo_json_1cf824e66837b819cf43b3b8229dd656_add (data) {
#             geo_json_1cf824e66837b819cf43b3b8229dd656
#                 .addData(data);
#         }
#             geo_json_1cf824e66837b819cf43b3b8229dd656_add({&quot;properties&quot;: {&quot;description&quot;: &quot;Boundary of the city of Vancouver, British Columbia, Canada&quot;, &quot;name&quot;: &quot;Vancouver&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_1cf824e66837b819cf43b3b8229dd656.addTo(map_02bde57d7a8fb99976d2d659a6078228);
#
#
#             var marker_1b521f64a9a2a1011a15ad1119a1cdb3 = L.marker(
#                 [49.2622822, -123.1142145],
#                 {}
#             ).addTo(map_02bde57d7a8fb99976d2d659a6078228);
#
#
#             var icon_79a3969737cee34e28f3b871e95a57c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1b521f64a9a2a1011a15ad1119a1cdb3.setIcon(icon_79a3969737cee34e28f3b871e95a57c6);
#
#
#             marker_1b521f64a9a2a1011a15ad1119a1cdb3.bindTooltip(
#                 `&lt;div&gt;
#                      0001 10th &amp; Cambie: 23287
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3818eb57f519dead76842ae873a0f196 = L.marker(
#                 [49.28645885053061, -123.12102864288579],
#                 {}
#             ).addTo(map_02bde57d7a8fb99976d2d659a6078228);
#
#
#             var icon_19479e954a1bb844dbcdd14db0e0581c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3818eb57f519dead76842ae873a0f196.setIcon(icon_19479e954a1bb844dbcdd14db0e0581c);
#
#
#             marker_3818eb57f519dead76842ae873a0f196.bindTooltip(
#                 `&lt;div&gt;
#                      0002 Burrard Station (Melville &amp; Dunsmuir): 17527
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf364ad2f8c23c0748d0a98c472374d6 = L.marker(
#                 [49.2744594, -123.1217156],
#                 {}
#             ).addTo(map_02bde57d7a8fb99976d2d659a6078228);
#
#
#             var icon_e073c826b4f71216c0204a844a6f9078 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cf364ad2f8c23c0748d0a98c472374d6.setIcon(icon_e073c826b4f71216c0204a844a6f9078);
#
#
#             marker_cf364ad2f8c23c0748d0a98c472374d6.bindTooltip(
#                 `&lt;div&gt;
#                      0004 Yaletown-Roundhouse Station: 19472
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0dc5653161f9d14af047e9c4f0c6dc28 = L.marker(
#                 [49.2797102, -123.1100831],
#                 {}
#             ).addTo(map_02bde57d7a8fb99976d2d659a6078228);
#
#
#             var icon_5280c90119a5279477d0bc8d26f5f8fb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0dc5653

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import folium
import pandas as pd
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_21768\3612916735.py:2: UserWarning:
#
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#
# C:\Users\prana\AppData\Local\Temp\ipykernel_21768\3612916735.py:3: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`

# %%
app = dash.Dash(__name__)

# Define the layout of your app
app.layout = html.Div([
    html.H1("Bike Stations in Vancouver"),
    html.Div(id='map-container'),
    dcc.RangeSlider(
            id='month-range-slider',
            marks={i: month[:3] for i, month in enumerate(sorted(set(item['Month'] for item in marker_locations)))},
            min=0,
            max=len(set(item['Month'] for item in marker_locations)) - 1,
            value=[0, len(set(item['Month'] for item in marker_locations)) - 1]
        ),
    dcc.Input(id='dummy-input', value='', style={'display': 'none'})  # Dummy input with a hidden style
])

# Define callback to update the map
@app.callback(
    Output('map-container', 'children'),
    [Input('month-range-slider', 'value')]  # RangeSlider input
)
def update_map(value):
    # Convert float values to integers
    value = [int(v) for v in value]

    # Filter marker locations based on selected months
    months = sorted(set(item['Month'] for item in marker_locations))
    start_month = months[value[0]]
    end_month = months[value[1]]
    filtered_marker_locations = [item for item in marker_locations if start_month <= item['Month'] <= end_month]

    # Calculate total count
    total_count = sum(item['Total Count'] for item in filtered_marker_locations)

    # Create a Folium map centered around Vancouver
    map_vancouver = folium.Map(location=[49.2827, -123.1207], zoom_start=12)

    # Add GeoJSON boundary to the map
    folium.GeoJson(vancouver_geojson).add_to(map_vancouver)

    # Add markers to specific locations
    for item in filtered_marker_locations:
        location = item["Coordinates"]
        name = item["Station"]
        info = int(item["Total Count"])
        folium.Marker(
            location=location,
            icon=folium.Icon(icon='bicycle', prefix='fa', color='red'),
            tooltip=f"{name}: {info}"
        ).add_to(map_vancouver)

    # Save the map to HTML and return it
    map_html = map_vancouver.get_root().render()
    return html.Iframe(srcDoc=map_html, width='100%', height='600')

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True, port=8058)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim

# Function to get coordinates from station name
def get_coordinates(station_name):
    geolocator = Nominatim(user_agent="station_locator")
    location = geolocator.geocode(station_name)
    if location:
        return location.latitude, location.longitude
    else:
        print(f"Coordinates for {station_name} not found")
        return None, None

get_coordinates('0308 Seymour & Cordova, Vancouver')
# List of station names
#names = ('David Lam Park, Vancouver', '0136 David Lam Park-West')
# Get coordinates for each station
#coordinates = get_coordinates('1000 Vancouver PRIDE Valet Station')
# Out:
# Coordinates for 0308 Seymour & Cordova, Vancouver not found
# (None, None)

# %%
len(coordinates)
# Out:
# 71

# %%
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
import time

# Function to get coordinates from station name with retry logic
def get_coordinates_with_retry(station_name, max_retries=3, delay=1):
    geolocator = Nominatim(user_agent="station_locator")
    retries = 0
    while retries < max_retries:
        try:
            location = geolocator.geocode(station_name)
            if location:
                return location.latitude, location.longitude
            else:
                print(f"Coordinates for {station_name} not found")
                return None, None
        except Exception as e:
            #print(f"Error: {e}. Retrying...")
            retries += 1
            time.sleep(delay)
    print(f"Failed to get coordinates for {station_name} after {max_retries} retries")
    return None, None

station = sorted(df['Departure station'].unique())
coordinates = []

for s in station:
    coordinate = get_coordinates_with_retry(s)
    coordinates.append(coordinate)
# Out:
# Coordinates for 0002 Burrard Station (Melville & Dunsmuir) not found
# Coordinates for 0007 12th & Yukon (City Hall) not found
# Coordinates for 0025 Homer & Robson (Vancouver Public Library) not found
# Coordinates for 0058 Richards & Smithe not found
# Coordinates for 0060 Bidwell & Burnaby not found
# Failed to get coordinates for 0070 10th & Granville after 3 retries
# Failed to get coordinates for 0071 14th & Granville after 3 retries
# Failed to get coordinates for 0081 7th & Heather after 3 retries
# Coordinates for 0100 Stanley Park - Prospect Point not found
# Failed to get coordinates for 0106 Heather & 14th after 3 retries
# Failed to get coordinates for 0107 8th & Ontario after 3 retries
# Failed to get coordinates for 0119 3rd & Quebec after 3 retries
# Failed to get coordinates for 0132 14th & Ontario after 3 retries
# Failed to get coordinates for 0136 David Lam Park - West after 3 retries
# Coordinates for 0153 Arbutus Greenway & Fir not found
# Coordinates for 0154 Kitsilano Beach Park not found
# Failed to get coordinates for 0176 10th & Ontario after 3 retries
# Failed to get coordinates for 0177 Quebec & 1st after 3 retries
# Coordinates for 0196 Hornby & Drake not found
# Failed to get coordinates for 0258 13th & St George after 3 retries
# Coordinates for 0278 15th & Victoria (Trout Lake) not found
# Failed to get coordinates for 0283 15th & Knight after 3 retries
# Coordinates for 0313 Nelson & Denman not found
# Coordinates for 0314 Rolston & Granville not found
# Coordinates for 0414 Dunbar & 6th not found
# Coordinates for 0440 Point Grey & Blenheim not found
# Coordinates for 0443 Balaclava & 6th not found
# Coordinates for 0450 Point Grey & Bayswater not found
# Failed to get coordinates for 0452 8th & Macdonald after 3 retries
# Coordinates for 0511 18th & Heather not found
# Coordinates for 0516 Heather & 29th not found
# Failed to get coordinates for 0554 Ontario & 23rd after 3 retries
# Coordinates for 0611 Wall & Eton not found
# Coordinates for 0631 Lakewood & Triumph not found
# Coordinates for 0642 Franklin & Nanaimo not found
# Coordinates for 0716 Sasamat & 10th not found
# Coordinates for 0980 Workshop - Balancer Bike Check In not found
# Coordinates for 0981 Workshop - Service Complete not found
# Coordinates for 0982 Workshop - Bike Testing not found
# Coordinates for 0987 Quebec Yard - Rogers not found
# Coordinates for 0992 Workshop - Return to Smoove not found
# Coordinates for 0994 Workshop - Transmitter Testing not found
# Coordinates for 0995 Workshop - Transmitter On Deck not found
# Coordinates for 0997 Workshop - Demo Station not found
# Coordinates for 1000 Vancouver PRIDE Valet Station not found
# Coordinates for 2132 IK Barber Learning Centre not found
# Coordinates for 3000 Temporary Station - Celebration of Light not found

# %%
coordinates
# Out:
# [(49.2622822, -123.1142145),
#  (49.2857921, -123.1209655),
#  (49.2744594, -123.1217156),
#  (49.2797102, -123.1100831),
#  (49.2665609, -123.1156986),
#  (49.2606046, -123.1134246),
#  (49.2642151, -123.1178195),
#  (49.270861, -123.1150229),
#  (49.2686127, -123.1180201),
#  (49.2716914, -123.1042968),
#  (49.282223, -123.11418428602579),
#  (32.787818, -96.843131),
#  (33.50697272225913, -83.94686468589317),
#  (49.2871315, -123.1186171),
#  (49.2735635, -123.1179519),
#  (49.2827328, -123.1220614),
#  (49.285583, -123.1126026),
#  (49.2860026, -123.116602),
#  (49.2796591, -123.1162932),
#  (49.2774968, -123.114236),
#  (49.275649, -123.1170024),
#  (49.2875014, -123.1420991),
#  (49.2826816, -123.107005),
#  (49.2880013, -123.1420794),
#  (49.2885183, -123.1393327),
#  (49.2890985, -123.121827),
#  (49.2901111, -123.12703),
#  (49.2858689, -123.1272595),
#  (49.2806129, -123.12478),
#  (49.2799185, -123.1274469),
#  (49.2855326, -123.138385),
#  (49.2892686, -123.1326555),
#  (49.2736703, -123.1270617),
#  (49.2752543, -123.1325611),
#  (49.289712, -123.1440153),
#  (49.2853146, -123.134325),
#  (49.2833805, -123.1310401),
#  (49.2846283, -123.1086152),
#  (49.2797995, -123.1079267),
#  (49.2780481, -123.1057008),
#  (49.2793015, -123.1017685),
#  (49.2738549, -123.114558),
#  (None, None),
#  (None, None),
#  (49.2815126, -123.1201536),
#  (49.2761224, -123.1145372),
#  (49.2727532, -123.1477204),
#  (49.2695442, -123.1378336),
#  (-33.8879553, 19.1088449),
#  (49.2652855, -123.1381984),
#  (49.2625924, -123.13888),
#  (49.2589687, -123.1393495),
#  (49.2587688, -123.1152956),
#  (49.2668059, -123.1047506),
#  (49.2620812, -123.1018465),
#  (7.1099864, 125.4984911),
#  (49.2682673, -123.1478672),
#  (49.2757002, -123.14245),
#  (49.2765028, -123.1189009),
#  (49.2777729, -123.1208527),
#  (49.2650786, -123.1194282),
#  (49.2757543, -123.1243609),
#  (49.2781965, -123.1369457),
#  (49.281178, -123.139029),
#  (49.2837789, -123.1360038),
#  (49.2802978, -123.1352757),
#  (49.2781301, -123.1305274),
#  (49.2918468, -123.1407852),
#  (49.2932024, -123.1386077),
#  (49.2881444, -123.1320198),
#  (49.2810403, -123.1044111),
#  (49.2831979, -123.1204825),
#  (None, None),
#  (49.2992547, -123.1303286),
#  (49.2953393, -123.1504703),
#  (49.3026103, -123.1556398),
#  (49.2943135, -123.1487139),
#  (49.2986558, -123.1212092),
#  (49.2592543, -123.120086),
#  (49.2638169, -123.1052878),
#  (49.2707276, -123.1461997),
#  (49.2656102, -123.1525342),
#  (49.267233, -123.1531863),
#  (49.2622734, -123.12616),
#  (49.2576909, -123.1532696),
#  (49.2592367, -123.1482565),
#  (49.2575397, -123.1484736),
#  (49.268217, -123.1030597),
#  (49.2905224, -123.136222),
#  (49.2860549, -123.1241903),
#  (49.2844582, -123.1111846),
#  (49.2808952, -123.130541),
#  (49.2803018, -123.1177147),
#  (49.25676, -123.1200251),
#  (49.2584988, -123.1048152),
#  (49.2568643, -123.1051257),
#  (49.2583966, -123.1007345),
#  (49.2709252, -123.1259935),
#  (49.2735405, -123.1298518),
#  (49.2771762, -123.1225069),
#  (49.2677813, -123.1457589),
#  (49.2652965, -123.1458088),
#  (49.2832577, -123.1422531),
#  (49.2676184, -123.1277051),
#  (-26.1980722, 28.2605653),
#  (49.2759635, -123.1460073),
#  (49.2756105, -123.102698),
#  (49.2841519, -123.0999589),
#  (49.2589484, -123.152613),
#  (49.2667647, -123.1411494),
#  (49.2760877, -123.1513261),
#  (49.2683741, -123.157433),
#  (49.2840577, -123.095047),
#  (38.03037775, 23.742301632832376),
#  (49.2617669, -123.1314892),
#  (49.2639535, -123.1126594),
#  (-35.7005877, 173.7567862),
#  (49.2622196, -123.1093161),
#  (49.2699811, -123.1095854),
#  (49.2702382, -123.106335),
#  (49.2620546, -123.1047007),
#  (49.2703309, -123.1027341),
#  (49.2611458, -123.0974366),
#  (49.2589114, -123.1095676),
#  (49.2619701, -123.0973416),
#  (49.2820425, -123.1330451),
#  (49.2702636, -123.1349844),
#  (49.2877533, -123.1239048),
#  (49.2650434, -123.1237691),
#  (49.2651767, -123.1310129),
#  (49.2736718, -123.1022542),
#  (None, None),
#  (55.940818, -4.25003),
#  (12.8827623, 77.6054113),
#  (49.2785197, -123.1000524),
#  (49.2915667, -123.1291772),
#  (49.2886688, -123.1182129),
#  (49.258781, -123.1271099),
#  (49.258866, -123.1435154),
#  (49.2717489, -123.1554804),
#  (49.2629314, -123.1433487),
#  (49.2636196, -123.099236),
#  (49.2876362, -123.1272215),
#  (49.2979505, -123.1306813),
#  (49.2594325, -123.1456168),
#  (49.2588295, -123.1313655),
#  (49.2776095, -123.095793),
#  (49.2802712, -123.0970897),
#  (49.2777049, -123.0917253),
#  (49.2825174, -123.1246795),
#  (49.2762933, -123.1065399),
#  (34.855344939713135, -84.10670288128748),
#  (41.2536794, -77.6099827),
#  (49.2776591, -123.0735579),
#  (49.2773948, -123.0704165),
#  (49.2803186, -123.0700656),
#  (49.2801197, -123.0741648),
#  (49.2806434, -123.084749),
#  (49.2792153, -123.0874912),
#  (49.2793622, -123.0909562),
#  (49.2839923, -123.0911062),
#  (49.274881, -123.0692936),
#  (49.2758553, -123.0719018),
#  (49.2737663, -123.0927082),
#  (49.2731002, -123.0699248),
#  (49.2649223, -123.0794519),
#  (49.2649024, -123.0812237),
#  (49.2713808, -123.0693525),
#  (49.2686186, -123.0700509),
#  (49.2669734, -123.0700235),
#  (49.2632295, -123.0704772),
#  (49.261412, -123.0701593),
#  (49.2612322, -123.0737544),
#  (49.2621862, -123.0814508),
#  (49.2623071, -123.0930671),
#  (49.2642309, -123.0738623),
#  (49.2666761, -123.0734696),
#  (49.2707346, -123.0736192),
#  (49.2731187, -123.0731844),
#  (49.2641012, -123.0707016),
#  (12.9149378, 77.5904564),
#  (49.2567266, -123.0965455),
#  (49.2581393, -123.096343),
#  (-34.003991, 22.4809282),
#  (49.2615005, -123.0893354),
#  (49.2634568, -123.0888362),
#  (49.2635225, -123.0956253),
#  (52.573353, 1.7187293),
#  (52.573353, 1.7187293),
#  (49.2801793, -123.0660122),
#  (49.2666307, -123.0658618),
#  (49.2611652, -123.0660014),
#  (49.2567901, -123.0656984),
#  (49.2839768, -123.0652119),
#  (49.2580237, -123.0833488),
#  (49.2579521, -123.0895274),
#  (49.2565028, -123.0754794),
#  (49.2832115, -123.0703905),
#  (49.2674701, -123.0907444),
#  (49.2652349, -123.0954559),
#  (49.2652155, -123.0906761),
#  (49.2848699, -123.128767),
#  (49.2809374, -123.1153534),
#  (-32.6376854, -62.6922562),
#  (49.2868529, -123.1289011),
#  (49.2595423, -123.114742),
#  (49.2903562, -123.1401608),
#  (49.2754249, -123.1277443),
#  (47.538178, -122.037603),
#  (49.252656, -123.067972),
#  (49.272223, -123.097988),
#  (36.859311, -76.143522),
#  (49.2685318, -123.190208),
#  (51.3526718, 1.4009661),
#  (49.2648033, -123.1858536),
#  (None, None),
#  (39.2953155, -76.594706),
#  (-25.7707513, 28.2780207),
#  (None, None),
#  (None, None),
#  (49.2640934, -123.173552),
#  (None, None),
#  (-36.8928385, 174.9299349),
#  (50.1346398, -5.5641389),
#  (49.2639092, -123.164243),
#  (49.272569, -123.159366),
#  (49.2479931, -123.153038),
#  (40.7518608, -73.870897),
#  (52.0369063, -1.852882),
#  (33.174729, -87.499412),
#  (None, None),
#  (None, None),
#  (49.2492072, -123.1161507),
#  (49.2451129, -123.1162559),
#  (49.2548234, -123.1148079),
#  (49.2516355, -123.1225685),
#  (None, None),
#  (49.2433945, -123.104914),
#  (49.2527004, -123.101258),
#  (13.0872604, 77.581543),
#  (12.9080657, 77.5843816),
#  (None, None),
#  (33.591596, -85.91286),
#  (None, None),
#  (None, None),
#  (51.6733353, 0.3797778),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (-6.6320177000000005, 31.1396084),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (46.0992612, 19.6724699),
#  (None, None),
#  (49.2809692, -123.0358795),
#  (49.27590825, -123.15217069777356),
#  (None, None),
#  (49.266796, -123.24763482487361),
#  (49.2622565, -123.24329295568945),
#  (None, None)]

# %%
len(coordinates)
# Out:
# 264

# %%
df2 = pd.DataFrame({'Station': station, 'Coordinates': coordinates})

# %%
df2[df2['Station'] == '0136 David Lam Park - West']
# Out:
#                        Station                 Coordinates
# 97  0136 David Lam Park - West  (49.2709252, -123.1259935)

# %%
df2.head(60)
# Out:
#                                            Station  \
# 0                               0001 10th & Cambie
# 1       0002 Burrard Station (Melville & Dunsmuir)
# 2                 0004 Yaletown-Roundhouse Station
# 3                           0005 Dunsmuir & Beatty
# 4                     0006 Olympic Village Station
# 5                    0007 12th & Yukon (City Hall)
# 6                                   0008 8th & Ash
# 7                          0009 Spyglass & Seawall
# 8                              0010 Stamps Landing
# 9                           0011 Ontario & Seawall
# 10                        0012 Dunsmuir & Richards
# 11                               0014 Canada Place
# 12                        0015 Granville & Georgia
# 13                           0016 Pender & Burrard
# 14                         0017 Marinaside & Davie
# 15                            0019 Robson & Hornby
# 16                        0021 Cordova & Granville
# 17                            0024 Hornby & Pender
# 18  0025 Homer & Robson (Vancouver Public Library)
# 19                            0026 Beatty & Robson
# 20                            0027 Beatty & Nelson
# 21                              0028 Davie & Beach
# 22                           0030 Abbott & Cordova
# 23                            0031 Morton & Denman
# 24                             0032 Comox & Denman
# 25                             0034 Cordova & Bute
# 26                       0035 Hastings & Broughton
# 27                              0036 Bute & Robson
# 28                            0037 Hornby & Nelson
# 29                         0039 Helmcken & Burrard
# 30                            0040 Cardero & Davie
# 31                           0041 Cardero & Robson
# 32                         0044 Pacific & Richards
# 33                             0045 Beach & Hornby
# 34                             0047 Chilco & Beach
# 35                          0048 Comox & Broughton
# 36                               0050 Bute & Comox
# 37                             0052 Cambie & Water
# 38                            0053 Keefer & Abbott
# 39                             0054 Expo & Carrall
# 40                          0055 Keefer & Columbia
# 41                     0057 Marinaside & Cooperage
# 42                          0058 Richards & Smithe
# 43                          0060 Bidwell & Burnaby
# 44                         0063 Robson & Granville
# 45                              0064 Expo & Smithe
# 46                         0065 Cypress & Cornwall
# 47                             0066 Anderson & 2nd
# 48                             0068 Cypress & 10th
# 49                            0069 7th & Granville
# 50                           0070 10th & Granville
# 51                           0071 14th & Granville
# 52                              0072 14th & Cambie
# 53                              0073 Ontario & 5th
# 54                                0074 10th & Main
# 55                             0075 Arbutus & 10th
# 56                              0076 Cypress & 4th
# 57                                0077 Vanier Park
# 58                          0078 Nelson & Mainland
# 59                          0079 Nelson & Richards
#
#                                 Coordinates
# 0                (49.2622822, -123.1142145)
# 1                              (None, None)
# 2                (49.2744594, -123.1217156)
# 3                (49.2797102, -123.1100831)
# 4                (49.2665609, -123.1156986)
# 5                              (None, None)
# 6                (49.2642151, -123.1178195)
# 7                 (49.270861, -123.1150229)
# 8                (49.2686127, -123.1180201)
# 9                (49.2716914, -123.1042968)
# 10         (49.282223, -123.11418428602579)
# 11                  (32.787818, -96.843131)
# 12  (33.50697272225913, -83.94686468589317)
# 13               (49.2871315, -123.1186171)
# 14               (49.2735635, -123.1179519)
# 15               (49.2827328, -123.1220614)
# 16                (49.285583, -123.1126026)
# 17                (49.2860026, -123.116602)
# 18                             (None, None)
# 19                (49.2774968, -123.114236)
# 20                (49.275649, -123.1170024)
# 21               (49.2875014, -123.1420991)
# 22                (49.2826816, -123.107005)
# 23               (49.2880013, -123.1420794)
# 24               (49.2885183, -123.1393327)
# 25                (49.2890985, -123.121827)
# 26                 (49.2901111, -123.12703)
# 27               (49.2858689, -123.1272595)
# 28                 (49.2806129, -123.12478)
# 29               (49.2799185, -123.1274469)
# 30                (49.2855326, -123.138385)
# 31               (49.2892686, -123.1326555)
# 32               (49.2736703, -123.1270617)
# 33               (49.2752543, -123.1325611)
# 34                (49.289712, -123.1440153)
# 35                (49.2853146, -123.134325)
# 36               (49.2833805, -123.1310401)
# 37               (49.2846283, -123.1086152)
# 38               (49.2797995, -123.1079267)
# 39               (49.2780481, -123.1057008)
# 40               (49.2793015, -123.1017685)
# 41                (49.2738549, -123.114558)
# 42                             (None, None)
# 43                             (None, None)
# 44               (49.2815126, -123.1201536)
# 45               (49.2761224, -123.1145372)
# 46               (49.2727532, -123.1477204)
# 47               (49.2695442, -123.1378336)
# 48                (-33.8879553, 19.1088449)
# 49               (49.2652855, -123.1381984)
# 50                             (None, None)
# 51                             (None, None)
# 52               (49.2587688, -123.1152956)
# 53               (49.2668059, -123.1047506)
# 54               (49.2620812, -123.1018465)
# 55                 (7.1099864, 125.4984911)
# 56               (49.2682673, -123.1478672)
# 57                 (49.2757002, -123.14245)
# 58               (49.2765028, -123.1189009)
# 59               (49.2777729, -123.1208527)

# %%
df2.to_csv('data.csv', index=False)

# %%
import pandas as pd
import calendar
import plotly.express as px

# Assuming combined_df has 'Departure' column
# Convert 'Departure' to datetime
combined_df['Departure'] = pd.to_datetime(combined_df['Departure'])

# Extract month and season
combined_df['Month'] = combined_df['Departure'].dt.month
combined_df['Season'] = combined_df['Departure'].dt.month % 12 // 3 + 1

# Map season and month names
combined_df['Season'] = combined_df['Season'].map({1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'})
combined_df['Month'] = combined_df['Month'].apply(lambda x: calendar.month_abbr[x])

# Group by season, then by month, and calculate average count of bike departures
seasonal_bike_count = combined_df.groupby(['Season', 'Month']).size().reset_index(name='Bike Count')
average_counts = seasonal_bike_count.groupby(['Month', 'Season'])['Bike Count'].mean().reset_index()

# Define custom sort order for months
month_order = ['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov']

# Sort the DataFrame by the 'Month' column using the custom order
average_counts = average_counts.loc[average_counts['Month'].isin(month_order)]
average_counts['Month'] = pd.Categorical(average_counts['Month'], categories=month_order, ordered=True)
average_counts = average_counts.sort_values(by='Month')

# Create separate line plots for each season
fig_winter = px.line(
    average_counts[average_counts['Month'].isin(['Dec', 'Jan', 'Feb', 'Mar'])],
    x='Month',
    y='Bike Count',
    title='Average Bike Departures in Winter',
    line_shape='linear',
    color_discrete_sequence=['blue'],
    hover_data={'Month': True, 'Bike Count': True, 'Season': True}  # Add 'Season' to hover
)

fig_spring = px.line(
    average_counts[average_counts['Month'].isin(['Mar', 'Apr', 'May', 'Jun'])],
    x='Month',
    y='Bike Count',
    title='Average Bike Departures in Spring',
    line_shape='linear',
    color_discrete_sequence=['green'],
    hover_data={'Month': True, 'Bike Count': True, 'Season': True}  # Add 'Season' to hover
)

fig_summer = px.line(
    average_counts[average_counts['Month'].isin(['Jun', 'Jul', 'Aug', 'Sep'])],
    x='Month',
    y='Bike Count',
    title='Average Bike Departures in Summer',
    line_shape='linear',
    color_discrete_sequence=['red'],
    hover_data={'Month': True, 'Bike Count': True, 'Season': True}  # Add 'Season' to hover
)

fig_fall = px.line(
    average_counts[average_counts['Month'].isin(['Sep', 'Oct', 'Nov'])],
    x='Month',
    y='Bike Count',
    title='Average Bike Departures in Fall',
    line_shape='linear',
    color_discrete_sequence=['yellow'],
    hover_data={'Month': True, 'Bike Count': True, 'Season': True}  # Add 'Season' to hover
)

# Combine the line plots
fig_combined = fig_winter.add_traces(fig_spring.data)
fig_combined.add_traces(fig_summer.data)
fig_combined.add_traces(fig_fall.data)

# Update layout
fig_combined.update_layout(
    title='Average Bike Departures by Season and Month',
    xaxis_title='Month',
    yaxis_title='Average Bike Departure Count',
    xaxis=dict(
        rangeslider=dict(
            visible=True
        ),
        type='category'
    )
)

# Show the plot
fig_combined.show()
# Out:
# <div>                            <div id="60e4ffeb-e940-4279-b76a-a6dacdb71c57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60e4ffeb-e940-4279-b76a-a6dacdb71c57")) {                    Plotly.newPlot(                        "60e4ffeb-e940-4279-b76a-a6dacdb71c57",                        [{"customdata":[["Winter"],["Winter"],["Winter"],["Spring"]],"hovertemplate":"Month=%{x}\u003cbr\u003eBike Count=%{y}\u003cbr\u003eSeason=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"blue","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Dec","Jan","Feb","Mar"],"xaxis":"x","y":[59986.0,93316.0,45770.0,72465.0],"yaxis":"y","type":"scatter"},{"customdata":[["Spring"],["Spring"],["Spring"],["Summer"]],"hovertemplate":"Month=%{x}\u003cbr\u003eBike Count=%{y}\u003cbr\u003eSeason=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"green","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Mar","Apr","May","Jun"],"xaxis":"x","y":[72465.0,74885.0,140171.0,157688.0],"yaxis":"y","type":"scatter"},{"customdata":[["Summer"],["Summer"],["Summer"],["Fall"]],"hovertemplate":"Month=%{x}\u003cbr\u003eBike Count=%{y}\u003cbr\u003eSeason=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"red","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Jun","Jul","Aug","Sep"],"xaxis":"x","y":[157688.0,201263.0,192161.0,156016.0],"yaxis":"y","type":"scatter"},{"customdata":[["Fall"],["Fall"],["Fall"]],"hovertemplate":"Month=%{x}\u003cbr\u003eBike Count=%{y}\u003cbr\u003eSeason=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"yellow","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Sep","Oct","Nov"],"xaxis":"x","y":[156016.0,110782.0,78793.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0 ...
